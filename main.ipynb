# %% [markdown]
# # Antimicrobial Resistance Knowledge Graph

# %% [markdown]
# ## Abstact
#
# This study explores the integration of antibiotic resistance data from GenBank and RefSeq databases into the publicly accessible Knowledge Graph, Wikidata. Antibiotic resistance poses a significant global health threat, with the misuse of antibiotics leading to the emergence of resistant strains. The project focuses on modeling proteins, genes, chromosomes, bacterial strains, and species in Wikidata, using a comprehensive dataset from the National Center for Biotechnology Information (NCBI). The data cleaning process involves addressing discrepancies and extracting crucial information from the linked databases. Despite challenges, the implementation in Wikidata progresses, with ongoing efforts to link bacterial strains, genes, and proteins. The study highlights the need for standardized entries in databases and emphasizes the potential impact of integrating antibiotic resistance information into Wikidata for global accessibility and collaborative contributions.

# %% [markdown]
# ## Background and Motivation
#
# Antibiotics play a crucial role in the treatment of bacterial infections. The use of antibiotics annually saves millions of lives, but it also accelerates the growth of livestock in factory farming. Due to the increased and sometimes unnecessary use of antibiotics, individual microorganisms develop resistance, rendering antibiotics ineffective. The development of antibiotic resistance is caused by genetic mutations that occur randomly in bacteria. If these mutations have a positive impact on the bacterium's survival, it survives the antibiotic treatment and passes on the positive traits to other bacteria or the next generation.
#
# Improper use of antibiotics, especially in developing countries, has led to the prevalence of many antibiotic-resistant bacteria today. Just as different antibiotics have different mechanisms of action (for example, Beta-Lactam targets the bacterial cell wall), bacteria also develop various defense mechanisms. For instance, bacteria can form an efflux pump, which expels already entered antibiotics from the cell.
#
# Infection with antibiotic-resistant bacteria poses a high risk to humans, as medical treatment becomes impossible. The World Health Organization (WHO) classifies Antimicrobial Resistance (AMR) as one of the three greatest medical threats, referring to it as a silent pandemic due to the high annual death toll (1.27 million people). By 2050, the WHO estimates that the number could rise to 10 million deaths per year, far surpassing the annual mortality rate of cancer.
#
# Although various health organizations are aware of numerous bacterial strains encoding antibiotic-resistant proteins, these databases are not interconnected, despite the urgent need for such integration. This work focuses on incorporating the largest publicly accessible database from the National Center for Biotechnology Information (NCBI) into a publicly accessible Knowledge Graph (Wikidata). Medial staff, scientists and interested people can easily access the knowledge from Wikidata. [1]

# %% [markdown]
# ## Material and Methods
#
# Since the data in the publicly accessible Wikidata Knowledge Graph is intended to be available to everyone, the implementation concept follows the modeling of proteins, genes, chromosomes, bacterial strains, and bacterial species. The premise is that the bacterial species is already present in Wikidata, and only the further sequence needs to be modeled.
#
# As a data source, a public database from the National Center for Biotechnology Information (NIH) is chosen [2]. This database consists of approximately 10,000 proteins that cause antibiotic resistances in bacteria. The protein is linked to the type of antibiotic resistance, as well as to links to nucleotides and proteins in the Refseq and GenBank databases. To model the sequence described above, consisting of protein, gene, chromosome, and bacterial strain starting from the bacterial species, the names of the gene and bacterial strain must be extracted from the linked Refseq and GenBank databases. Using the "bioservice EUtils" and the Refseq or GenBank references, the aforementioned information is extracted from the databases. Redundancies are deliberately built (e.g., extracting the bacterial species via Refseq and GenBank, as well as via protein and nucleotide) to subsequently combine information or choose the most complete data source.

# %%
import pandas as pd 
import urllib
import time 
import numpy as np 
import bioservice_fetcher as biof 
import os 
from typing import Optional

# %% [markdown]
# ### Fetch data from NCBI database
#
# The read dataframe contains keys to access the protein, nucleotide either via Reference Sequence (RefSeq) database or genbank. Lets load the first two columns of the dataframe and read some values. First try is to get the data from the RefSeq-database.

# %%
# Reads everything from the linked refseq and genbank databases that could possible be interesting for this project

def fetch_data(read_from_web: bool = False, amount: Optional[int] = None) -> pd.DataFrame: 
    """
    if fetch_data_switch is True data will be fetched from NCBI and interesting things will be read from genbank or refseq database -- caution: Takes for ages 
    else data will be read from last time -- should be used in most of the cases 
    """
    if read_from_web: 
        # will take ~ 12h 
        url = "https://ftp.ncbi.nlm.nih.gov/pathogen/Antimicrobial_resistance/AMRFinderPlus/database/latest/ReferenceGeneCatalog.txt"
        df = pd.read_csv(urllib.request.urlopen(url), delimiter="\t")
        if amount is not None:
            df = df.sample(amount)
        df[["refseq_parent_taxon", "refseq_protein", "refseq_parent_taxon2"]] = df.apply(biof.get_protein_and_parent, axis=1)
        print(1)
        df[["refseq_gene", "refseq_protein2", "refseq_genome", "refseq_organism", "refseq_tax_id"]] = df.apply(biof.get_strain_and_gene, axis=1)
        print(2)
        df[["genbank_organism", "genbank_strain"]] = df.apply(biof.get_organism_strain_via_prot,axis=1)
        print(3)
        df[["genbank_organism2", "genbank_strain2", "genbank_tax_id"]] = df.apply(biof.get_organism_strain_via_nuc, axis=1)
        df.to_csv("resistance_df.csv", index=False)
    else: 
        if not os.path.exists("resistance_df.csv"): 
            print("Cannot read from hard drive because file does not exist -- set read from web switch to True")
            return None
        df = pd.read_csv("resistance_df.csv")
    return df


df = fetch_data(False)
df.sample(5, random_state=19)
# Out:
#            allele gene_family whitelisted_taxa  \
# 3774   blaOXA-823      blaOXA              NaN
# 6706          NaN        narB              NaN
# 139   aac(6')-29a  aac(6')-29              NaN
# 7508          NaN      tet(D)              NaN
# 1398     blaCAR-1      blaCAR              NaN
#
#                                          product_name scope type subtype  \
# 3774     OXA-10 family class D beta-lactamase OXA-823  core  AMR     AMR
# 6706  ionophore ABC transporter permease subunit NarB  plus  AMR     AMR
# 139    aminoglycoside N-acetyltransferase AAC(6')-29a  core  AMR     AMR
# 7508       tetracycline efflux MFS transporter Tet(D)  core  AMR     AMR
# 1398         subclass B3 metallo-beta-lactamase CAR-1  core  AMR     AMR
#
#                class                         subclass  \
# 3774     BETA-LACTAM                      BETA-LACTAM
# 6706       IONOPHORE  MADURAMICIN/NARASIN/SALINOMYCIN
# 139   AMINOGLYCOSIDE                   AMINOGLYCOSIDE
# 7508    TETRACYCLINE                     TETRACYCLINE
# 1398     BETA-LACTAM                       CARBAPENEM
#
#      refseq_protein_accession  ...  \
# 3774           WP_136512103.1  ...
# 6706                      NaN  ...
# 139            WP_064190968.1  ...
# 7508           WP_001039466.1  ...
# 1398           WP_011094382.1  ...
#
#                                       refseq_gene  \
# 3774   Pseudomonas aeruginosa HUPM19015969 blaOXA
# 6706                                          NaN
# 139             Pseudomonas aeruginosa aac(6')-29
# 7508                   Shigella sonnei 119 tet(D)
# 1398  Pectobacterium atrosepticum SCRI1043 blaCAR
#
#                                      refseq_protein2 refseq_genome  \
# 3774    OXA-10 family class D beta-lactamase OXA-823           NaN
# 6706                                             NaN           NaN
# 139   aminoglycoside N-acetyltransferase AAC(6')-29a           NaN
# 7508      tetracycline efflux MFS transporter Tet(D)           NaN
# 1398        subclass B3 metallo-beta-lactamase CAR-1           NaN
#
#                            refseq_organism refseq_tax_id  \
# 3774                Pseudomonas aeruginosa     taxon:287
# 6706                                   NaN           NaN
# 139                 Pseudomonas aeruginosa     taxon:287
# 7508                       Shigella sonnei     taxon:624
# 1398  Pectobacterium atrosepticum SCRI1043  taxon:218491
#
#                           genbank_organism  genbank_strain  \
# 3774                Pseudomonas aeruginosa    HUPM19015969
# 6706                  Enterococcus faecium          WT1145
# 139                                    NaN             NaN
# 7508                       Shigella sonnei             119
# 1398  Pectobacterium atrosepticum SCRI1043        SCRI1043
#
#                          genbank_organism2  genbank_strain2  genbank_tax_id
# 3774                Pseudomonas aeruginosa     HUPM19015969       taxon:287
# 6706                  Enterococcus faecium           WT1145      taxon:1352
# 139                 Pseudomonas aeruginosa              NaN       taxon:287
# 7508                       Shigella sonnei              119       taxon:624
# 1398  Pectobacterium atrosepticum SCRI1043         SCRI1043    taxon:218491
#
# [5 rows x 38 columns]

# %% [markdown]
# ## STRAIN
#
# Because there is quite a bit of data present, my goal is to extract the right name of the bacterial strain. Therefore, I am going to find the best data source of organism name and combine it with the best source of the exact strain name

# %%
df.keys()
# Out:
# Index(['allele', 'gene_family', 'whitelisted_taxa', 'product_name', 'scope',
#        'type', 'subtype', 'class', 'subclass', 'refseq_protein_accession',
#        'refseq_nucleotide_accession', 'curated_refseq_start',
#        'genbank_protein_accession', 'genbank_nucleotide_accession',
#        'genbank_strand', 'genbank_start', 'genbank_stop', 'refseq_strand',
#        'refseq_start', 'refseq_stop', 'pubmed_reference', 'blacklisted_taxa',
#        'synonyms', 'hierarchy_node', 'db_version', 'refseq_parent_taxon',
#        'refseq_protein', 'refseq_parent_taxon2', 'refseq_gene',
#        'refseq_protein2', 'refseq_genome', 'refseq_organism', 'refseq_tax_id',
#        'genbank_organism', 'genbank_strain', 'genbank_organism2',
#        'genbank_strain2', 'genbank_tax_id'],
#       dtype='object')

# %%
# Just by looking into this small random sampled dataframe "refseq organism", "genbank_organsim" and "genbank_organism2" yield similar results, 
# altough "refseq_organism" has less information
# "refseq_parent_taxon" and "refseq_parent_taxon2" sometimes have the same information as the others and sometimes have a much higher taxon (e.g. line 8816 "Bacteria")
# For extracting the right organism name I am going to look closer into "refseq_organism", "genbank_organism" and "ganbank_organism2"
df[["refseq_parent_taxon", "refseq_parent_taxon2",  "refseq_organism", "genbank_organism", "genbank_organism2"]].sample(10, random_state=100)
# Out:
#            refseq_parent_taxon      refseq_parent_taxon2  \
# 758                        NaN                       NaN
# 9222        Enterobacteriaceae        Enterobacteriaceae
# 8816                  Bacteria                  Bacteria
# 3993        Klebsiella oxytoca        Klebsiella oxytoca
# 4874          Escherichia coli          Escherichia coli
# 6956      Citrobacter freundii      Citrobacter freundii
# 277           Pseudomonadaceae          Pseudomonadaceae
# 3978  Klebsiella michiganensis  Klebsiella michiganensis
# 8247              Enterococcus              Enterococcus
# 2520       Lelliottia amnigena       Lelliottia amnigena
#
#                refseq_organism                           genbank_organism  \
# 758                        NaN                    Acidiphilium multivorum
# 9222                       NaN                            Shigella sonnei
# 8816                       NaN  Escherichia coli str. K-12 substr. MG1655
# 3993        Klebsiella oxytoca                         Klebsiella oxytoca
# 4874          Escherichia coli                           Escherichia coli
# 6956      Citrobacter freundii                                        NaN
# 277         Pseudomonas putida                                        NaN
# 3978  Klebsiella michiganensis                   Klebsiella michiganensis
# 8247                       NaN                       Enterococcus faecium
# 2520       Lelliottia amnigena                        Lelliottia amnigena
#
#                               genbank_organism2
# 758                     Acidiphilium multivorum
# 9222                            Shigella sonnei
# 8816  Escherichia coli str. K-12 substr. MG1655
# 3993                         Klebsiella oxytoca
# 4874                           Escherichia coli
# 6956                       Citrobacter freundii
# 277                          Pseudomonas putida
# 3978                   Klebsiella michiganensis
# 8247                       Enterococcus faecium
# 2520                        Lelliottia amnigena

# %%
# The above impression solifies: refseq organism obivously contains the most empty fields
df[["genbank_organism", "genbank_organism2", "refseq_organism"]].isna().sum()
# Out:
# genbank_organism      368
# genbank_organism2       0
# refseq_organism      2499
# dtype: int64

# %%
#cases where organisms in genbank via protein (genbank_organism), genbank via nuclotide and refseq do not match 

diff_organism_df = df.loc[(df["genbank_organism"] != df["genbank_organism2"]) | (df["genbank_organism"] != df["refseq_organism"]), ["genbank_organism", 
                                                                                                                                    "genbank_organism2", 
                                                                                                                                    "refseq_organism"]]
diff_organism_df.sample(10, random_state=8)
# Out:
#                                        genbank_organism  \
# 7123                              Staphylococcus aureus
# 6122                                   Escherichia coli
# 770                               Enterococcus sp. JM4C
# 8458  Campylobacter jejuni subsp. jejuni NCTC 11168 ...
# 6540                          Enterobacter roggenkampii
# 999                                                 NaN
# 8553                             Pseudomonas aeruginosa
# 5718                                   Escherichia coli
# 3126                                                NaN
# 5948                           Bacillus bingmayongensis
#
#                                       genbank_organism2  \
# 7123                              Staphylococcus aureus
# 6122                                   Escherichia coli
# 770                               Enterococcus sp. JM4C
# 8458  Campylobacter jejuni subsp. jejuni NCTC 11168 ...
# 6540                          Enterobacter roggenkampii
# 999                       Acinetobacter baumannii AB4A3
# 8553                             Pseudomonas aeruginosa
# 5718                                   Escherichia coli
# 3126                             Pseudomonas aeruginosa
# 5948                           Bacillus bingmayongensis
#
#                     refseq_organism
# 7123                            NaN
# 6122                            NaN
# 770                             NaN
# 8458                            NaN
# 6540                            NaN
# 999   Acinetobacter baumannii AB4A3
# 8553                            NaN
# 5718                            NaN
# 3126         Pseudomonas aeruginosa
# 5948                            NaN

# %%
# As can be seen there are 35 issues where organism found via genbank (nucleotid) and via genbank (protein) are different 
# What should be done here? Are these alternative names? -- Expert knowledge requiered: I'm going to drop them 
(x1 := diff_organism_df.loc[diff_organism_df["genbank_organism"] != diff_organism_df["genbank_organism2"], ["genbank_organism", "genbank_organism2"]].dropna())
# Out:
#                                        genbank_organism  \
# 126   Salmonella enterica subsp. enterica serovar Ty...
# 601                        Bacillus anthracis str. Ames
# 5475                              Escherichia coli K-12
# 5697                       Clostridioides difficile 630
# 5721                         Bacillus cereus ATCC 14579
# 5942                         Bacillus cereus ATCC 14579
# 6214                         Bacillus cereus ATCC 14579
# 6217                   Staphylococcus epidermidis RP62A
# 6220                         Bacillus phage lambda Ba03
# 6257  Salmonella enterica subsp. enterica serovar Ty...
# 6258  Salmonella enterica subsp. enterica serovar Ty...
# 6263                         Bacillus cereus ATCC 14579
# 6264                         Bacillus cereus ATCC 14579
# 6265                         Bacillus cereus ATCC 14579
# 6275                         Bacillus cereus ATCC 14579
# 6305                         Bacillus cereus ATCC 14579
# 6306                       Bacillus anthracis str. Ames
# 6542  Salmonella enterica subsp. enterica serovar Ty...
# 6543  Salmonella enterica subsp. enterica serovar Ty...
# 6724                         Bacillus cereus ATCC 14579
# 6869                         Bacillus cereus ATCC 14579
# 6870                       Bacillus anthracis str. Ames
# 7106                       Bacillus anthracis str. Ames
# 7168  Salmonella enterica subsp. enterica serovar Ty...
# 7176                                      Phage Gifsy-2
# 7178                       Bacillus anthracis str. Ames
# 7417                       Clostridioides difficile 630
# 7418                       Clostridioides difficile 630
# 7419                       Clostridioides difficile 630
# 7420                       Clostridioides difficile 630
# 7421                       Clostridioides difficile 630
# 8027                     Streptococcus pneumoniae AP200
# 8036                     Streptococcus pneumoniae AP200
# 8042                     Streptococcus pneumoniae AP200
# 9308  Salmonella enterica subsp. enterica serovar Ty...
#
#                                    genbank_organism2
# 126                           Salmonella virus Fels2
# 601                       Bacillus phage lambda Ba02
# 5475                                Escherichia coli
# 5697                   Peptoclostridium phage p630P2
# 5721                         Bacillus phage phBC6A52
# 5942                         Bacillus phage phBC6A52
# 6214                         Bacillus phage phBC6A52
# 6217  Staphylococcus epidermidis RP62A phage SP-beta
# 6220                      Bacillus phage lambda Ba02
# 6257                          Salmonella virus Fels2
# 6258                          Salmonella virus Fels2
# 6263                         Bacillus phage phBC6A52
# 6264                         Bacillus phage phBC6A52
# 6265                         Bacillus phage phBC6A52
# 6275                         Bacillus phage phBC6A52
# 6305                         Bacillus phage phBC6A52
# 6306                      Bacillus phage lambda Ba02
# 6542                          Salmonella virus Fels2
# 6543                          Salmonella virus Fels2
# 6724                         Bacillus phage phBC6A52
# 6869                         Bacillus phage phBC6A52
# 6870                      Bacillus phage lambda Ba02
# 7106                      Bacillus phage lambda Ba02
# 7168                          Salmonella virus Fels2
# 7176                          Salmonella virus Fels2
# 7178                      Bacillus phage lambda Ba02
# 7417                   Peptoclostridium phage p630P2
# 7418                   Peptoclostridium phage p630P2
# 7419                   Peptoclostridium phage p630P2
# 7420                   Peptoclostridium phage p630P2
# 7421                   Peptoclostridium phage p630P2
# 8027                  Streptococcus phage PhiSpn_200
# 8036                  Streptococcus phage PhiSpn_200
# 8042                  Streptococcus phage PhiSpn_200
# 9308                          Salmonella virus Fels2

# %%
# Furthermore there are 5 issues between genbank via nucleotide and refseq 
# Are these alternative names? Expert knowledge requiered: I'm going to drop them as I'm not sure
(x2 := diff_organism_df.loc[diff_organism_df["genbank_organism"] != diff_organism_df["refseq_organism"], ["genbank_organism", 
                                                                                                          "refseq_organism"]].dropna())
# Out:
#                      genbank_organism  \
# 2032                Acinetobacter sp.
# 4045         Klebsiella michiganensis
# 5056              Salmonella enterica
# 6220       Bacillus phage lambda Ba03
# 6236  Cytobacillus massiliigabonensis
#
#                                         refseq_organism
# 2032                            Acinetobacter baumannii
# 4045                      Klebsiella michiganensis M5al
# 5056  Salmonella enterica subsp. enterica serovar In...
# 6220                       Bacillus anthracis str. Ames
# 6236                        Bacillus massiliigabonensis

# %% [markdown]
# I am going to choose the organism found by genbank via nucleotid as base organism, because it has no NaN and seems to be complete

# %%
# drop data instances where I'm unsure 
df.drop(set(x1.index).union(set(x2.index)), inplace=True)

# %%
# Genbank_strain carrys either redundant information or no information at all -- genbank_strain2 will therefore be selected
df.loc[(df["genbank_strain2"] != df["genbank_strain"]) & ~(df["genbank_strain"].isna()), ["genbank_strain2", "genbank_strain", "genbank_organism2"]]
# Out:
# Empty DataFrame
# Columns: [genbank_strain2, genbank_strain, genbank_organism2]
# Index: []

# %%
# Often the strain name in as expected to be in genbank_strain2, somtimes it is already included in genbank organism
# e.g. line 7743: Clostridium sp. MLG080-1 
df.loc[:, ["genbank_strain2", "genbank_organism2"]].sample(10, random_state=50)
# Out:
#      genbank_strain2            genbank_organism2
# 9018            FA19        Neisseria gonorrhoeae
# 7743        MLG080-1     Clostridium sp. MLG080-1
# 9165           WHO_U        Neisseria gonorrhoeae
# 3013         2318902       Pseudomonas aeruginosa
# 4               FC1K  Mycolicibacterium fortuitum
# 6795      SKLX003475        Klebsiella pneumoniae
# 1363           G4074     Elizabethkingia miricola
# 4295          185584       Pseudomonas aeruginosa
# 9014            FA19        Neisseria gonorrhoeae
# 5168      13S00929-3             Escherichia coli

# %% [markdown]
# To find the correct and full strain name, I will combine "genbank_strain2" and "genbank_organism2", only if strain is not included in organism. Else, the organism itself will be selected.

# %%
def check_for_combination(df_row: pd.Series) -> bool:
    """
    Checks if genbank_organism and genbank_strain should be connected to one strain
    """
    if not isinstance(df_row["genbank_strain2"], str): 
        # don't combine organism and strain if is NaN --> Is this correct? 
        return False
    return not (df_row["genbank_strain2"].upper() in df_row["genbank_organism2"].upper())
    
    
df["strain"] = np.where(df.apply(check_for_combination , axis=1), 
                           df["genbank_organism2"] + " " + df["genbank_strain2"], 
                           df["genbank_organism2"])
df[["genbank_strain2", "genbank_organism2", "strain"]].sample(10, random_state=5)
# Out:
#      genbank_strain2                          genbank_organism2  \
# 5358             NaN                      Staphylococcus aureus
# 850             HA-2                               Hafnia alvei
# 9038        VRCO0432                      Klebsiella pneumoniae
# 4021           SG271                    Klebsiella spallanzanii
# 7357          NIPH56                    Acinetobacter baumannii
# 5862            13H1                           Escherichia coli
# 2529            HD24                      Klebsiella pneumoniae
# 613              NaN                       uncultured bacterium
# 8818            K-12  Escherichia coli str. K-12 substr. MG1655
# 4861            KK19                      Klebsiella pneumoniae
#
#                                          strain
# 5358                      Staphylococcus aureus
# 850                           Hafnia alvei HA-2
# 9038             Klebsiella pneumoniae VRCO0432
# 4021              Klebsiella spallanzanii SG271
# 7357             Acinetobacter baumannii NIPH56
# 5862                      Escherichia coli 13H1
# 2529                 Klebsiella pneumoniae HD24
# 613                        uncultured bacterium
# 8818  Escherichia coli str. K-12 substr. MG1655
# 4861                 Klebsiella pneumoniae KK19

# %%
# As can be seen sometimes strain now contains only the parent taxon name (e.g. line Staphylococcus aureus), which is not correct. 
# I will drop instances where strain is no longer than two words. Expert knowledge required  
df = df[~(df["strain"].str.split().str.len() <= 2)]
df[["genbank_strain2", "genbank_organism2", "strain"]].sample(10, random_state=5)
# Out:
#      genbank_strain2            genbank_organism2  \
# 6455          EC3769             Escherichia coli
# 5176   CLSiS 1590/96        Klebsiella pneumoniae
# 8198          VC4477     Burkholderia cenocepacia
# 2566       blaCLHK-3     Laribacter hongkongensis
# 1466              BS             Escherichia coli
# 5081            3343             Escherichia coli
# 8839            PAO1  Pseudomonas aeruginosa PAO1
# 3313          268/2C      Acinetobacter baumannii
# 3345          XM1570  Acinetobacter calcoaceticus
# 9152    PNUSAS062732          Salmonella enterica
#
#                                    strain
# 6455              Escherichia coli EC3769
# 5176  Klebsiella pneumoniae CLSiS 1590/96
# 8198      Burkholderia cenocepacia VC4477
# 2566   Laribacter hongkongensis blaCLHK-3
# 1466                  Escherichia coli BS
# 5081                Escherichia coli 3343
# 8839          Pseudomonas aeruginosa PAO1
# 3313       Acinetobacter baumannii 268/2C
# 3345   Acinetobacter calcoaceticus XM1570
# 9152     Salmonella enterica PNUSAS062732

# %% [markdown]
# ## Gene

# %%
# Gene is only in one column -- everything Nan is dropped 
# Gene_family was included in orginal dataframe and matches with the found gene -- Should be okay: expert knowledge 
# If gene family is not in found gene (refseq_gene) data instance will be dropped 
# Where do I get the Entrez ID from ? -- Expert knowledge, I think is not existant?
df.dropna(subset="refseq_gene", inplace=True)
df = df[df.apply(lambda x: x["gene_family"] in x["refseq_gene"], axis=1)]
df[["gene_family", "refseq_gene"]].sample(10, random_state=10)
# Out:
#      gene_family                                   refseq_gene
# 2444      blaKPC               Klebsiella pneumoniae 1B blaKPC
# 7566      tet(M)             Staphylococcus aureus 4520 tet(M)
# 5341      blaVIM  Klebsiella oxytoca NMI1536_13 unnamed blaVIM
# 5226      blaTMB        Acinetobacter pittii MRY12-0142 blaTMB
# 4928      blaSHV             Klebsiella pneumoniae 86-4 blaSHV
# 4600      blaPDC      Pseudomonas aeruginosa Paebeta-25 blaPDC
# 3715      blaOXA   Acinetobacter baumannii 17-VT7014T-1 blaOXA
# 5030      blaTEM          Klebsiella pneumoniae Va32447 blaTEM
# 3169      blaOXA            Acinetobacter baumannii 255 blaOXA
# 2386      blaKPC         Klebsiella pneumoniae ES06_R04 blaKPC

# %% [markdown]
# ## Search for connection to Wikidata

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
def search_parent_taxon(df_row: pd.Series) -> str:
    """
    Searches in wikidata for a species of bacterium which matches the two first words of strain
    Sometime we have abbreviations for example Achromobacter sp. -- nobody knows if this is rather Achromobacter spanius or Achromobacter spiritinus -- This is all rather unusable
    """
    parent = df_row["strain"].split()[:2]
    print(df_row["strain"])
    abbreviation = False
    for i, word in enumerate(parent): 
        if word[-1] == ".": 
            abbreviation = True
            parent[i] = word[:-1]
    parent = " ".join(parent).lower()
    query = f"""SELECT ?item ?itemLabel ?itemDescription
    WHERE {{
      # ?item rdfs:label ?label;
            schema:description "species of bacterium"@en.
      
      FILTER(LANG(?label) = "en" && CONTAINS(LCASE(?label), "{parent}"))
      
      SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }}
    }}
    LIMIT 10
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    while True:
        try:
            results = sparql.query().convert().get("results").get("bindings")
            break
        except (urllib.error.HTTPError, urllib.request.HTTPError): 
            time.sleep(5)
        except: 
            pass
    results = [(item.get("item").get("value"), item.get("itemLabel").get("value")) for item in results]
    if not results:
        return None
    if abbreviation: 
        return [res[0] for res in results] if len(results) > 1 else results[0][0]
    else: 
        for res in results: 
            if res[1].lower() in parent: 
                return res[0]


get_from_wikidata_switch = False
if get_from_wikidata_switch:
    # Will take ~ 2h
    df["parent_taxon"] = df.apply(search_parent_taxon, axis=1)
    df.to_csv("resistance_df2.csv", index=False)
else: 
    df = pd.read_csv("resistance_df2.csv")

# %%
# The dataframe now contains a column called parent taxon which leads to the corresponding wikidata species of bacterium 
# Some parent taxon could not be found -- will be dropped later 
df[["product_name", "refseq_organism",  "strain", "parent_taxon", "refseq_gene"]].sample(5, random_state=9)
# Out:
#                                            product_name  \
# 1420  extended-spectrum class A beta-lactamase CTX-M-74
# 5304         tetracycline efflux MFS transporter Tet(L)
# 1453                      class C beta-lactamase DHA-18
# 3415                     class C beta-lactamase PDC-156
# 780    extended-spectrum class C beta-lactamase ADC-256
#
#               refseq_organism                           strain  \
# 1420     Enterobacter cloacae       Enterobacter cloacae JF216
# 5304  Latilactobacillus sakei    Latilactobacillus sakei Rits9
# 1453      Morganella morganii       Morganella morganii 984080
# 3415   Pseudomonas aeruginosa   Pseudomonas aeruginosa 1231451
# 780   Acinetobacter baumannii  Acinetobacter baumannii 20A3025
#
#                                  parent_taxon  \
# 1420  http://www.wikidata.org/entity/Q4038096
# 5304                                      NaN
# 1453  http://www.wikidata.org/entity/Q2696880
# 3415    http://www.wikidata.org/entity/Q31856
# 780   http://www.wikidata.org/entity/Q3241189
#
#                                  refseq_gene
# 1420     Enterobacter cloacae JF216 blaCTX-M
# 5304  Lactobacillus sakei Rits9 pLS55 tet(L)
# 1453       Morganella morganii 984080 blaDHA
# 3415   Pseudomonas aeruginosa 1231451 blaPDC
# 780   Acinetobacter baumannii 20A3025 blaADC

# %% [markdown]
# ### Handle special cases
#
# For example: Escherichia coli K-12
# I found this randomly -- could be more -- expert knowledge required

# %%
df.keys()
# Out:
# Index(['allele', 'gene_family', 'whitelisted_taxa', 'product_name', 'scope',
#        'type', 'subtype', 'class', 'subclass', 'refseq_protein_accession',
#        'refseq_nucleotide_accession', 'curated_refseq_start',
#        'genbank_protein_accession', 'genbank_nucleotide_accession',
#        'genbank_strand', 'genbank_start', 'genbank_stop', 'refseq_strand',
#        'refseq_start', 'refseq_stop', 'pubmed_reference', 'blacklisted_taxa',
#        'synonyms', 'hierarchy_node', 'db_version', 'refseq_parent_taxon',
#        'refseq_protein', 'refseq_parent_taxon2', 'refseq_gene',
#        'refseq_protein2', 'refseq_genome', 'refseq_organism', 'refseq_tax_id',
#        'genbank_organism', 'genbank_strain', 'genbank_organism2',
#        'genbank_strain2', 'genbank_tax_id', 'strain', 'parent_taxon'],
#       dtype='object')

# %%
df["parent_taxon"] = np.where((df["genbank_organism2"].str.lower().str.contains("escherichia coli")) & (df["genbank_strain2"] == "K-12"), 
                             "https://www.wikidata.org/entity/Q21399437", 
                             df["parent_taxon"])
df[df["parent_taxon"] == "https://www.wikidata.org/entity/Q21399437"]
# Out:
#      allele gene_family whitelisted_taxa  \
# 459     NaN   aph(4)-Ia              NaN
# 4443    NaN       catA2              NaN
#
#                                            product_name scope type subtype  \
# 459       aminoglycoside O-phosphotransferase APH(4)-Ia  core  AMR     AMR
# 4443  type A-2 chloramphenicol O-acetyltransferase C...  core  AMR     AMR
#
#                class         subclass refseq_protein_accession  ...  \
# 459   AMINOGLYCOSIDE       HYGROMYCIN           WP_000742814.1  ...
# 4443        PHENICOL  CHLORAMPHENICOL           WP_012477888.1  ...
#
#      refseq_genome        refseq_organism refseq_tax_id  \
# 459            NaN  Escherichia coli K-12   taxon:83333
# 4443           NaN  Escherichia coli K-12   taxon:83333
#
#            genbank_organism genbank_strain      genbank_organism2  \
# 459   Escherichia coli K-12           K-12  Escherichia coli K-12
# 4443  Escherichia coli K-12           K-12  Escherichia coli K-12
#
#       genbank_strain2 genbank_tax_id                 strain  \
# 459              K-12    taxon:83333  Escherichia coli K-12
# 4443             K-12    taxon:83333  Escherichia coli K-12
#
#                                    parent_taxon
# 459   https://www.wikidata.org/entity/Q21399437
# 4443  https://www.wikidata.org/entity/Q21399437
#
# [2 rows x 40 columns]

# %% [markdown]
# ## Drop useless data instances

# %%
# drop rows where no wikidata parent taxon (species of bacterium) was found 
df = df.dropna(subset="parent_taxon")

# %%
# These data instances are made up of abbreviations, which make it unclear to which taxon they belong. 
# e.g. Streptomyces sp. 769 could belong to Streptomyces sp. myrophorea (Q60748847), Streptomyces spiramyceticus (Q104909301) or Streptomyces sporangiiformans (Q104957131)
# Expert Knowledge required -- They also need to be dropped 
df.loc[:, "parent_taxon"] = df["parent_taxon"].astype(str)
df.loc[df["parent_taxon"].str.contains("\[|\]"), ["strain", "parent_taxon"]]
# Out:
#                                   strain  \
# 38                  Streptomyces sp. 769
# 46       Streptomyces sp. GBA 94-10 4N24
# 52                Streptomyces sp. SPB78
# 59          Streptomyces sp. NRRL S-1831
# 74             Streptomyces sp. MBRL 601
# 80                  Streptomyces sp. M10
# 82                  Streptomyces sp. KE1
# 89          Streptomyces sp. NRRL F-4711
# 90          Streptomyces sp. NRRL F-4707
# 1953        Streptomyces sp. NRRL S-1868
# 1954        Streptomyces sp. NRRL F-5053
# 2734      Achromobacter sp. 2015clin2ach
# 2735      Achromobacter sp. 2015clin4ach
# 4300         Achromobacter sp. sallbros1
# 4430           Streptomyces sp. MBRL 601
# 4501              Clostridium sp. AF37-7
# 4698            Lactobacillus sp. PC121B
# 5180  Streptomyces sp. WAC 01438 WAC1438
# 5196            Streptomyces sp. WAC4747
# 5247        Corynebacterium sp. L2-79-05
# 5305                     Bacillus sp. 24
# 5310                    Bacillus sp. R89
# 5405              Clostridium sp. MLG480
# 5406            Clostridium sp. MLG080-1
# 5407              Clostridium sp. MLG055
# 5409              Clostridium sp. MLG101
# 5501           Clostridium sp. CCRI-9842
# 5537           Clostridium sp. CCRI-9842
# 5552           Clostridium sp. CCRI-9842
#
#                                            parent_taxon
# 38    ['http://www.wikidata.org/entity/Q60748845', '...
# 46    ['http://www.wikidata.org/entity/Q60748845', '...
# 52    ['http://www.wikidata.org/entity/Q60748845', '...
# 59    ['http://www.wikidata.org/entity/Q60748845', '...
# 74    ['http://www.wikidata.org/entity/Q60748845', '...
# 80    ['http://www.wikidata.org/entity/Q60748845', '...
# 82    ['http://www.wikidata.org/entity/Q60748845', '...
# 89    ['http://www.wikidata.org/entity/Q60748845', '...
# 90    ['http://www.wikidata.org/entity/Q60748845', '...
# 1953  ['http://www.wikidata.org/entity/Q60748845', '...
# 1954  ['http://www.wikidata.org/entity/Q60748845', '...
# 2734  ['http://www.wikidata.org/entity/Q16973926', '...
# 2735  ['http://www.wikidata.org/entity/Q16973926', '...
# 4300  ['http://www.wikidata.org/entity/Q16973926', '...
# 4430  ['http://www.wikidata.org/entity/Q60748845', '...
# 4501  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 4698  ['http://www.wikidata.org/entity/Q3825343', 'h...
# 5180  ['http://www.wikidata.org/entity/Q60748845', '...
# 5196  ['http://www.wikidata.org/entity/Q60748845', '...
# 5247  ['http://www.wikidata.org/entity/Q21262825', '...
# 5305  ['http://www.wikidata.org/entity/Q798286', 'ht...
# 5310  ['http://www.wikidata.org/entity/Q798286', 'ht...
# 5405  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 5406  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 5407  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 5409  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 5501  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 5537  ['http://www.wikidata.org/entity/Q2979669', 'h...
# 5552  ['http://www.wikidata.org/entity/Q2979669', 'h...

# %%
df = df[~df["parent_taxon"].str.contains("\[|\]")]

# %%
len(df) # About half of the data is lost after everything is clearead
# Out:
# 4563

# %%
# I now have a dataframe which contains antibiotic resistance class / subclass, protein name, gene, species of bacterium (wikidata) and bacterial strain 
# Could be implemented into wikidata like this 
df[["class", "subclass", "product_name", "refseq_gene", "parent_taxon", "strain"]].sample(5, random_state=5)
# Out:
#                class              subclass  \
# 3752     BETA-LACTAM         CEPHALOSPORIN
# 266   AMINOGLYCOSIDE  KANAMYCIN/TOBRAMYCIN
# 543      BETA-LACTAM         CEPHALOSPORIN
# 5074       QUINOLONE             QUINOLONE
# 1095     BETA-LACTAM         CEPHALOSPORIN
#
#                                            product_name  \
# 3752  inhibitor-resistant class C beta-lactamase PDC...
# 266        aminoglycoside 6'-N-acetyltransferase AacA34
# 543   cephalosporin-hydrolyzing class C beta-lactama...
# 5074  quinolone resistance pentapeptide repeat prote...
# 1095                     class C beta-lactamase CMY-124
#
#                                 refseq_gene  \
# 3752   Pseudomonas aeruginosa 208176 blaPDC
# 266   Klebsiella pneumoniae KP-PNK-1 aacA34
# 543      Enterobacter cloacae 963327 blaACT
# 5074     Citrobacter freundii V1 pCFV1 qnrB
# 1095      Citrobacter freundii DNS-2 blaCMY
#
#                                  parent_taxon                          strain
# 3752    http://www.wikidata.org/entity/Q31856   Pseudomonas aeruginosa 208176
# 266    http://www.wikidata.org/entity/Q132592  Klebsiella pneumoniae KP-PNK-1
# 543   http://www.wikidata.org/entity/Q4038096     Enterobacter cloacae 963327
# 5074  http://www.wikidata.org/entity/Q5122842         Citrobacter freundii V1
# 1095  http://www.wikidata.org/entity/Q5122842      Citrobacter freundii DNS-2

# %%
# NCBI taxonomy ID is in all data instances regardsless of access via refseq or genbank the same 
any(df["genbank_tax_id"] != df["refseq_tax_id"])
# Out:
# False

# %%
# But the NCBI taxonomy ID has not always enough depth -- e.g. line 3664 taxon 470 -> https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi leads to acinetobacter baumannii 
# but not to the corresponding strain (16-02P46T-1) which does not exist yet. 
# Line 59 Serratia marcescens W2.3 leads to the wanted result: https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi --> 1218513
# What sould be done here? Expert knowledge required -- I don't feel well implementing the data without the correct taxonomy ID
# I will drop rows where strain and genbank_organism2 don't match - basically undo combination step further up
df[["strain", "genbank_organism2", "genbank_strain2", "genbank_tax_id"]].sample(10, random_state=1)
# Out:
#                                                  strain  \
# 5129                            Citrobacter braakii 107
# 2998                Acinetobacter baumannii 16-02P46T-1
# 3013                    Acinetobacter baumannii 17A1872
# 4113                      Klebsiella pneumoniae 1409130
# 30                             Serratia marcescens W2.3
# 3965                   Pseudomonas libanensis DSM 17149
# 865                     Acinetobacter baumannii 23A3701
# 4389                        Vibrio alginolyticus Vb1833
# 445   Salmonella enterica subsp. enterica serovar Ty...
# 3497                      Pseudomonas aeruginosa 163604
#
#                                       genbank_organism2 genbank_strain2  \
# 5129                                Citrobacter braakii             107
# 2998                            Acinetobacter baumannii     16-02P46T-1
# 3013                            Acinetobacter baumannii         17A1872
# 4113                              Klebsiella pneumoniae         1409130
# 30                             Serratia marcescens W2.3            W2.3
# 3965                             Pseudomonas libanensis       DSM 17149
# 865                             Acinetobacter baumannii         23A3701
# 4389                               Vibrio alginolyticus          Vb1833
# 445   Salmonella enterica subsp. enterica serovar Ty...             NaN
# 3497                             Pseudomonas aeruginosa          163604
#
#      genbank_tax_id
# 5129    taxon:57706
# 2998      taxon:470
# 3013      taxon:470
# 4113      taxon:573
# 30    taxon:1218513
# 3965    taxon:75588
# 865       taxon:470
# 4389      taxon:663
# 445     taxon:90371
# 3497      taxon:287

# %%
# These would be the data instances where I feel comfortable, including into Wikidata, because I have the correct NCBI taxonomy ID for others to check. 
# Now there are only 312 instances left 
df = df.loc[df.apply(lambda x: str(x["genbank_strain2"]) in x["genbank_organism2"], axis=1), :]
print(len(df))
df[["strain", "genbank_organism2", "genbank_strain2", "genbank_tax_id"]].sample(10)
# Out:
# 312
#                                              strain  \
# 248               Macrococcus caseolyticus JCSC5402
# 20                    Saccharophagus degradans 2-40
# 2594  Acinetobacter bouvetii DSM 14964 = CIP 107468
# 4649            Mycobacterium tuberculosis CCDC5180
# 1022                   Vibrio parahaemolyticus S105
# 5461             Desulfitobacterium hafniense PCP-1
# 4715                           Vibrio cholerae MO10
# 2560           Acinetobacter calcoaceticus ANC 3680
# 627                     Acinetobacter baumannii AYE
# 2256                   Acinetobacter baumannii A424
#
#                                   genbank_organism2 genbank_strain2  \
# 248               Macrococcus caseolyticus JCSC5402        JCSC5402
# 20                    Saccharophagus degradans 2-40            2-40
# 2594  Acinetobacter bouvetii DSM 14964 = CIP 107468      CIP 107468
# 4649            Mycobacterium tuberculosis CCDC5180        CCDC5180
# 1022                   Vibrio parahaemolyticus S105            S105
# 5461             Desulfitobacterium hafniense PCP-1           PCP-1
# 4715                           Vibrio cholerae MO10            MO10
# 2560           Acinetobacter calcoaceticus ANC 3680        ANC 3680
# 627                     Acinetobacter baumannii AYE             AYE
# 2256                   Acinetobacter baumannii A424            A424
#
#      genbank_tax_id
# 248    taxon:458233
# 20     taxon:203122
# 2594  taxon:1120925
# 4649   taxon:443150
# 1022  taxon:1394641
# 5461  taxon:1090321
# 4715   taxon:345072
# 2560  taxon:1217653
# 627    taxon:509173
# 2256  taxon:1082934

# %%
df.to_csv("resistance_df3.csv", index=False)

# %% [markdown]
# ## Results
#
# After selecting and combining the best data sources (see the commented code above), a dataframe remains containing information about the protein, its encoding gene, and the bacterial strain. To establish a connection with Wikidata, the first two words of the bacterial strain (often the name of the corresponding bacterial species) are used in a SPARQL Wikidata query to find the associated bacterial species or its Wikidata qualifier. In addition to the respective names, identifiers are available to link each name with the NCBI database. This connection is crucial to provide users with more comprehensive information and allow experts to make improvements.
#
# Furthermore, data is cleaned if there are missing or conflicting details at critical points. The most extensive cleaning, associated with the greatest data loss, occurs when it was observed that the found NCBI Taxonomy ID does not always refer to the bacterial strain but rather to higher taxa. This is unacceptable for Wikidata implementation, leading to the removal of such instances.
#
# In the final step, the data is implemented in Wikidata. Using "pywikibots," a connection is established. Firstly, if not already present, the bacterial strain is implemented with the NCBI taxonomy ID. Subsequently, the identified gene is implemented, referencing the bacterial strain. Finally, the gene encodes a protein that makes the bacterium antibiotic-resistant. This protein is also implemented with a corresponding reference to the gene and the Quick-Go reference "response to antibiotic" (GO:0046677).

# %%
df[df["genbank_organism2"] == "Sphingobium indicum B90A"]
# Out:
#         allele gene_family whitelisted_taxa  \
# 4043  blaSGM-3      blaSGM              NaN
# 4155  blaSIE-1      blaSIE              NaN
#
#                                   product_name scope type subtype  \
# 4043              class A beta-lactamase SGM-3  core  AMR     AMR
# 4155  subclass B3 metallo-beta-lactamase SIE-1  core  AMR     AMR
#
#             class     subclass refseq_protein_accession  ... refseq_genome  \
# 4043  BETA-LACTAM  BETA-LACTAM           WP_007688792.1  ...           NaN
# 4155  BETA-LACTAM  BETA-LACTAM           WP_007683232.1  ...           NaN
#
#                refseq_organism refseq_tax_id          genbank_organism  \
# 4043  Sphingobium indicum B90A  taxon:861109  Sphingobium indicum B90A
# 4155  Sphingobium indicum B90A  taxon:861109  Sphingobium indicum B90A
#
#      genbank_strain         genbank_organism2  genbank_strain2 genbank_tax_id  \
# 4043           B90A  Sphingobium indicum B90A             B90A   taxon:861109
# 4155           B90A  Sphingobium indicum B90A             B90A   taxon:861109
#
#                         strain                              parent_taxon
# 4043  Sphingobium indicum B90A  http://www.wikidata.org/entity/Q18392374
# 4155  Sphingobium indicum B90A  http://www.wikidata.org/entity/Q18392374
#
# [2 rows x 40 columns]

# %%
df.iloc[215:]
# Out:
#          allele gene_family        whitelisted_taxa  \
# 4043   blaSGM-3      blaSGM                     NaN
# 4044   blaSGM-4      blaSGM                     NaN
# 4048   blaSHD-1      blaSHD                     NaN
# 4049   blaSHN-1      blaSHN                     NaN
# 4155   blaSIE-1      blaSIE                     NaN
# ...         ...         ...                     ...
# 5562        NaN      vanX-I                     NaN
# 5614        NaN        vatI                     NaN
# 5626        NaN      vga(G)                     NaN
# 5628        NaN        vgbC                     NaN
# 5630  folP_F25I        folP  Streptococcus_pyogenes
#
#                                         product_name scope type subtype  \
# 4043                    class A beta-lactamase SGM-3  core  AMR     AMR
# 4044                    class A beta-lactamase SGM-4  core  AMR     AMR
# 4048        subclass B1 metallo-beta-lactamase SHD-1  core  AMR     AMR
# 4049        subclass B1 metallo-beta-lactamase SHN-1  core  AMR     AMR
# 4155        subclass B3 metallo-beta-lactamase SIE-1  core  AMR     AMR
# ...                                              ...   ...  ...     ...
# 5562                  D-Ala-D-Ala dipeptidase VanX-I  core  AMR     AMR
# 5614      streptogramin A O-acetyltransferase Vat(I)  core  AMR     AMR
# 5626  ABC-F type ribosomal protection protein Vga(G)  core  AMR     AMR
# 5628                    streptogramin B lyase Vgb(C)  core  AMR     AMR
# 5630                   dihydropteroate synthase FolP  core  AMR   POINT
#
#               class       subclass refseq_protein_accession  ...  \
# 4043    BETA-LACTAM    BETA-LACTAM           WP_007688792.1  ...
# 4044    BETA-LACTAM    BETA-LACTAM           WP_013846594.1  ...
# 4048    BETA-LACTAM     CARBAPENEM           WP_011495276.1  ...
# 4049    BETA-LACTAM     CARBAPENEM           WP_011497575.1  ...
# 4155    BETA-LACTAM    BETA-LACTAM           WP_007683232.1  ...
# ...             ...            ...                      ...  ...
# 5562   GLYCOPEPTIDE     VANCOMYCIN           WP_015943580.1  ...
# 5614  STREPTOGRAMIN  STREPTOGRAMIN           WP_071218948.1  ...
# 5626    LINCOSAMIDE    LINCOSAMIDE           WP_010989615.1  ...
# 5628  STREPTOGRAMIN  STREPTOGRAMIN           WP_071219112.1  ...
# 5630    SULFONAMIDE    SULFONAMIDE           WP_011017740.1  ...
#
#      refseq_genome                     refseq_organism  refseq_tax_id  \
# 4043           NaN            Sphingobium indicum B90A   taxon:861109
# 4044           NaN    Sphingobium chlorophenolicum L-1   taxon:690566
# 4048           NaN      Shewanella denitrificans OS217   taxon:318161
# 4049           NaN      Shewanella denitrificans OS217   taxon:318161
# 4155           NaN            Sphingobium indicum B90A   taxon:861109
# ...            ...                                 ...            ...
# 5562           NaN  Desulfitobacterium hafniense DCB-2   taxon:272564
# 5614           NaN             Paenibacillus sp. LC231  taxon:1120679
# 5626           NaN        Listeria monocytogenes EGD-e   taxon:169963
# 5628           NaN             Paenibacillus sp. LC231  taxon:1120679
# 5630           NaN     Streptococcus pyogenes MGAS8232   taxon:186103
#
#                         genbank_organism genbank_strain  \
# 4043            Sphingobium indicum B90A           B90A
# 4044    Sphingobium chlorophenolicum L-1            L-1
# 4048      Shewanella denitrificans OS217          OS217
# 4049      Shewanella denitrificans OS217          OS217
# 4155            Sphingobium indicum B90A           B90A
# ...                                  ...            ...
# 5562  Desulfitobacterium hafniense DCB-2          DCB-2
# 5614             Paenibacillus sp. LC231          LC231
# 5626        Listeria monocytogenes EGD-e          EGD-e
# 5628             Paenibacillus sp. LC231          LC231
# 5630     Streptococcus pyogenes MGAS8232       MGAS8232
#
#                        genbank_organism2  genbank_strain2 genbank_tax_id  \
# 4043            Sphingobium indicum B90A             B90A   taxon:861109
# 4044    Sphingobium chlorophenolicum L-1              L-1   taxon:690566
# 4048      Shewanella denitrificans OS217            OS217   taxon:318161
# 4049      Shewanella denitrificans OS217            OS217   taxon:318161
# 4155            Sphingobium indicum B90A             B90A   taxon:861109
# ...                                  ...              ...            ...
# 5562  Desulfitobacterium hafniense DCB-2            DCB-2   taxon:272564
# 5614             Paenibacillus sp. LC231            LC231  taxon:1120679
# 5626        Listeria monocytogenes EGD-e            EGD-e   taxon:169963
# 5628             Paenibacillus sp. LC231            LC231  taxon:1120679
# 5630     Streptococcus pyogenes MGAS8232         MGAS8232   taxon:186103
#
#                                   strain  \
# 4043            Sphingobium indicum B90A
# 4044    Sphingobium chlorophenolicum L-1
# 4048      Shewanella denitrificans OS217
# 4049      Shewanella denitrificans OS217
# 4155            Sphingobium indicum B90A
# ...                                  ...
# 5562  Desulfitobacterium hafniense DCB-2
# 5614             Paenibacillus sp. LC231
# 5626        Listeria monocytogenes EGD-e
# 5628             Paenibacillus sp. LC231
# 5630     Streptococcus pyogenes MGAS8232
#
#                                   parent_taxon
# 4043  http://www.wikidata.org/entity/Q18392374
# 4044   http://www.wikidata.org/entity/Q7576783
# 4048  http://www.wikidata.org/entity/Q21327861
# 4049  http://www.wikidata.org/entity/Q21327861
# 4155  http://www.wikidata.org/entity/Q18392374
# ...                                        ...
# 5562   http://www.wikidata.org/entity/Q3706079
# 5614  http://www.wikidata.org/entity/Q26270468
# 5626    http://www.wikidata.org/entity/Q292015
# 5628  http://www.wikidata.org/entity/Q26270468
# 5630    http://www.wikidata.org/entity/Q131271
#
# [97 rows x 40 columns]

# %%
# Including the bacterial strain into wikidata -- if it is not present upon creation it will be created 

from WikidataAdder import StrainWikidataAdder


def wikidata_wrapper(df_row: pd.Series) -> str | None: 
    wa = StrainWikidataAdder(df_row, sim=False) # Set sim to True unless you really want to include data into wikidata
    created = wa.create_strain()
    if created != 0:
        wa.add_instance_of_strain()
        wa.add_taxon_name()
        wa.add_parent_taxon()
        wa.add_ncbi_taxonomy_id()
        if created == 2:
            print("wait after creation")
            time.sleep(300) # This is needed to let wikidata enter newly create item into wikidata -- else risk of duplicate creation is high
        return wa.strain_page.getID()
    return None

# %%
# z = df.iloc[1:2].copy()
df["strain_wd_id"] = df.apply(wikidata_wrapper, axis=1)
# Out:
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124664031'}}]
# description already exists
# alias already exists
# Q124664031
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102987'}}]
# description already exists
# alias already exists
# Q21102987
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398890'}}]
# description already exists
# alias already exists
# Q21398890
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398562'}}]
# description already exists
# alias already exists
# Q21398562
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124664454'}}]
# description already exists
# alias already exists
# Q124664454
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124664466'}}]
# description already exists
# alias already exists
# Q124664466
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124664471'}}]
# description already exists
# alias already exists
# Q124664471
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124670721'}}]
# description already exists
# alias already exists
# Q124670721
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124670775'}}]
# description already exists
# alias already exists
# Q124670775
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690528'}}]
# description already exists
# alias already exists
# Q124690528
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690571'}}]
# description already exists
# alias already exists
# Q124690571
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690612'}}]
# description already exists
# alias already exists
# Q124690612
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690653'}}]
# description already exists
# alias already exists
# Q124690653
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690663'}}]
# description already exists
# alias already exists
# Q124690663
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690666'}}]
# description already exists
# alias already exists
# Q124690666
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690670'}}]
# description already exists
# alias already exists
# Q124690670
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690671'}}]
# description already exists
# alias already exists
# Q124690671
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690690'}}]
# description already exists
# alias already exists
# Q124690690
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690703'}}]
# description already exists
# alias already exists
# Q124690703
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690704'}}]
# description already exists
# alias already exists
# Q124690704
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690708'}}]
# description already exists
# alias already exists
# Q124690708
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690715'}}]
# description already exists
# alias already exists
# Q124690715
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690717'}}]
# description already exists
# alias already exists
# Q124690717
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690727'}}]
# description already exists
# alias already exists
# Q124690727
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690804'}}]
# description already exists
# alias already exists
# Q124690804
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690809'}}]
# description already exists
# alias already exists
# Q124690809
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690814'}}]
# description already exists
# alias already exists
# Q124690814
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102966'}}]
# description already exists
# alias already exists
# Q21102966
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690823'}}]
# description already exists
# alias already exists
# Q124690823
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690830'}}]
# description already exists
# alias already exists
# Q124690830
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690834'}}]
# description already exists
# alias already exists
# Q124690834
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690838'}}]
# description already exists
# alias already exists
# Q124690838
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690841'}}]
# description already exists
# alias already exists
# Q124690841
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690845'}}]
# description already exists
# alias already exists
# Q124690845
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690851'}}]
# description already exists
# alias already exists
# Q124690851
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690856'}}]
# description already exists
# alias already exists
# Q124690856
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690859'}}]
# description already exists
# alias already exists
# Q124690859
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690864'}}]
# description already exists
# alias already exists
# Q124690864
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690867'}}]
# description already exists
# alias already exists
# Q124690867
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690872'}}]
# description already exists
# alias already exists
# Q124690872
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690877'}}]
# description already exists
# alias already exists
# Q124690877
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690902'}}]
# description already exists
# alias already exists
# Q124690902
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690975'}}]
# description already exists
# alias already exists
# Q124690975
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691052'}}]
# description already exists
# alias already exists
# Q124691052
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691063'}}]
# description already exists
# alias already exists
# Q124691063
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691069'}}]
# description already exists
# alias already exists
# Q124691069
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691074'}}]
# description already exists
# alias already exists
# Q124691074
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691080'}}]
# description already exists
# alias already exists
# Q124691080
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691083'}}]
# description already exists
# alias already exists
# Q124691083
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691090'}}]
# description already exists
# alias already exists
# Q124691090
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691092'}}]
# description already exists
# alias already exists
# Q124691092
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691097'}}]
# description already exists
# alias already exists
# Q124691097
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691101'}}]
# description already exists
# alias already exists
# Q124691101
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691106'}}]
# description already exists
# alias already exists
# Q124691106
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691112'}}]
# description already exists
# alias already exists
# Q124691112
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102945'}}]
# description already exists
# alias already exists
# Q21102945
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691120'}}]
# description already exists
# alias already exists
# Q124691120
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21365260'}}]
# description already exists
# alias already exists
# Q21365260
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102920'}}]
# description already exists
# alias already exists
# Q21102920
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691097'}}]
# description already exists
# alias already exists
# Q124691097
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691247'}}]
# description already exists
# alias already exists
# Q124691247
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691250'}}]
# description already exists
# alias already exists
# Q124691250
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691255'}}]
# description already exists
# alias already exists
# Q124691255
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691260'}}]
# description already exists
# alias already exists
# Q124691260
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691262'}}]
# description already exists
# alias already exists
# Q124691262
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102994'}}]
# description already exists
# alias already exists
# Q21102994
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691267'}}]
# description already exists
# alias already exists
# Q124691267
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691268'}}]
# description already exists
# alias already exists
# Q124691268
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691274'}}]
# description already exists
# alias already exists
# Q124691274
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691083'}}]
# description already exists
# alias already exists
# Q124691083
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691279'}}]
# description already exists
# alias already exists
# Q124691279
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21399437'}}]
# description already exists
# alias already exists
# Q21399437
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691083'}}]
# description already exists
# alias already exists
# Q124691083
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398129'}}]
# description already exists
# alias already exists
# Q21398129
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691282'}}]
# description already exists
# alias already exists
# Q124691282
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102942'}}]
# description already exists
# alias already exists
# Q21102942
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691287'}}]
# description already exists
# alias already exists
# Q124691287
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691097'}}]
# description already exists
# alias already exists
# Q124691097
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691291'}}]
# description already exists
# alias already exists
# Q124691291
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691296'}}]
# description already exists
# alias already exists
# Q124691296
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691299'}}]
# description already exists
# alias already exists
# Q124691299
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691302'}}]
# description already exists
# alias already exists
# Q124691302
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691308'}}]
# description already exists
# alias already exists
# Q124691308
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691312'}}]
# description already exists
# alias already exists
# Q124691312
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691318'}}]
# description already exists
# alias already exists
# Q124691318
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691321'}}]
# description already exists
# alias already exists
# Q124691321
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691324'}}]
# description already exists
# alias already exists
# Q124691324
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691329'}}]
# description already exists
# alias already exists
# Q124691329
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691332'}}]
# description already exists
# alias already exists
# Q124691332
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691337'}}]
# description already exists
# alias already exists
# Q124691337
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691339'}}]
# description already exists
# alias already exists
# Q124691339
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691345'}}]
# description already exists
# alias already exists
# Q124691345
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691349'}}]
# description already exists
# alias already exists
# Q124691349
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691358'}}]
# description already exists
# alias already exists
# Q124691358
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691362'}}]
# description already exists
# alias already exists
# Q124691362
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691367'}}]
# description already exists
# alias already exists
# Q124691367
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691373'}}]
# description already exists
# alias already exists
# Q124691373
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691377'}}]
# description already exists
# alias already exists
# Q124691377
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691384'}}]
# description already exists
# alias already exists
# Q124691384
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124670890'}}]
# description already exists
# alias already exists
# Q124670890
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691390'}}]
# description already exists
# alias already exists
# Q124691390
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102920'}}]
# description already exists
# alias already exists
# Q21102920
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691398'}}]
# description already exists
# alias already exists
# Q124691398
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691401'}}]
# description already exists
# alias already exists
# Q124691401
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691409'}}]
# description already exists
# alias already exists
# Q124691409
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690690'}}]
# description already exists
# alias already exists
# Q124690690
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691413'}}]
# description already exists
# alias already exists
# Q124691413
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691419'}}]
# description already exists
# alias already exists
# Q124691419
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691422'}}]
# description already exists
# alias already exists
# Q124691422
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691429'}}]
# description already exists
# alias already exists
# Q124691429
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691434'}}]
# description already exists
# alias already exists
# Q124691434
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690715'}}]
# description already exists
# alias already exists
# Q124690715
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691447'}}]
# description already exists
# alias already exists
# Q124691447
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691470'}}]
# description already exists
# alias already exists
# Q124691470
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397631'}}]
# description already exists
# alias already exists
# Q21397631
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397727'}}]
# description already exists
# alias already exists
# Q21397727
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691484'}}]
# description already exists
# alias already exists
# Q124691484
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398217'}}]
# description already exists
# alias already exists
# Q21398217
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398963'}}]
# description already exists
# alias already exists
# Q21398963
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691495'}}]
# description already exists
# alias already exists
# Q124691495
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691506'}}]
# description already exists
# alias already exists
# Q124691506
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691517'}}]
# description already exists
# alias already exists
# Q124691517
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691527'}}]
# description already exists
# alias already exists
# Q124691527
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691535'}}]
# description already exists
# alias already exists
# Q124691535
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691544'}}]
# description already exists
# alias already exists
# Q124691544
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691547'}}]
# description already exists
# alias already exists
# Q124691547
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691551'}}]
# description already exists
# alias already exists
# Q124691551
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691554'}}]
# description already exists
# alias already exists
# Q124691554
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691567'}}]
# description already exists
# alias already exists
# Q124691567
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691578'}}]
# description already exists
# alias already exists
# Q124691578
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691587'}}]
# description already exists
# alias already exists
# Q124691587
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691591'}}]
# description already exists
# alias already exists
# Q124691591
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691664'}}]
# description already exists
# alias already exists
# Q124691664
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691680'}}]
# description already exists
# alias already exists
# Q124691680
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691688'}}]
# description already exists
# alias already exists
# Q124691688
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691692'}}]
# description already exists
# alias already exists
# Q124691692
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691697'}}]
# description already exists
# alias already exists
# Q124691697
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691707'}}]
# description already exists
# alias already exists
# Q124691707
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691711'}}]
# description already exists
# alias already exists
# Q124691711
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691714'}}]
# description already exists
# alias already exists
# Q124691714
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691718'}}]
# description already exists
# alias already exists
# Q124691718
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691724'}}]
# description already exists
# alias already exists
# Q124691724
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691727'}}]
# description already exists
# alias already exists
# Q124691727
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691732'}}]
# description already exists
# alias already exists
# Q124691732
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21065232'}}]
# description already exists
# alias already exists
# Q21065232
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691517'}}]
# description already exists
# alias already exists
# Q124691517
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690715'}}]
# description already exists
# alias already exists
# Q124690715
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691737'}}]
# description already exists
# alias already exists
# Q124691737
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691447'}}]
# description already exists
# alias already exists
# Q124691447
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691741'}}]
# description already exists
# alias already exists
# Q124691741
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691743'}}]
# description already exists
# alias already exists
# Q124691743
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691083'}}]
# description already exists
# alias already exists
# Q124691083
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691752'}}]
# description already exists
# alias already exists
# Q124691752
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691756'}}]
# description already exists
# alias already exists
# Q124691756
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691757'}}]
# description already exists
# alias already exists
# Q124691757
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691762'}}]
# description already exists
# alias already exists
# Q124691762
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691764'}}]
# description already exists
# alias already exists
# Q124691764
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691769'}}]
# description already exists
# alias already exists
# Q124691769
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691774'}}]
# description already exists
# alias already exists
# Q124691774
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21065230'}}]
# description already exists
# alias already exists
# Q21065230
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691779'}}]
# description already exists
# alias already exists
# Q124691779
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691787'}}]
# description already exists
# alias already exists
# Q124691787
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691318'}}]
# description already exists
# alias already exists
# Q124691318
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691329'}}]
# description already exists
# alias already exists
# Q124691329
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691321'}}]
# description already exists
# alias already exists
# Q124691321
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691797'}}]
# description already exists
# alias already exists
# Q124691797
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124690804'}}]
# description already exists
# alias already exists
# Q124690804
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691800'}}]
# description already exists
# alias already exists
# Q124691800
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691339'}}]
# description already exists
# alias already exists
# Q124691339
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691337'}}]
# description already exists
# alias already exists
# Q124691337
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691362'}}]
# description already exists
# alias already exists
# Q124691362
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691367'}}]
# description already exists
# alias already exists
# Q124691367
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691805'}}]
# description already exists
# alias already exists
# Q124691805
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691358'}}]
# description already exists
# alias already exists
# Q124691358
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691812'}}]
# description already exists
# alias already exists
# Q124691812
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691820'}}]
# description already exists
# alias already exists
# Q124691820
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691824'}}]
# description already exists
# alias already exists
# Q124691824
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691826'}}]
# description already exists
# alias already exists
# Q124691826
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691250'}}]
# description already exists
# alias already exists
# Q124691250
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691831'}}]
# description already exists
# alias already exists
# Q124691831
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691836'}}]
# description already exists
# alias already exists
# Q124691836
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691843'}}]
# description already exists
# alias already exists
# Q124691843
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691913'}}]
# description already exists
# alias already exists
# Q124691913
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691916'}}]
# description already exists
# alias already exists
# Q124691916
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691925'}}]
# description already exists
# alias already exists
# Q124691925
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691927'}}]
# description already exists
# alias already exists
# Q124691927
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691930'}}]
# description already exists
# alias already exists
# Q124691930
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691934'}}]
# description already exists
# alias already exists
# Q124691934
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691939'}}]
# description already exists
# alias already exists
# Q124691939
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691944'}}]
# description already exists
# alias already exists
# Q124691944
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691279'}}]
# description already exists
# alias already exists
# Q124691279
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691947'}}]
# description already exists
# alias already exists
# Q124691947
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691260'}}]
# description already exists
# alias already exists
# Q124691260
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691952'}}]
# description already exists
# alias already exists
# Q124691952
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691956'}}]
# description already exists
# alias already exists
# Q124691956
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21065234'}}]
# description already exists
# alias already exists
# Q21065234
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691957'}}]
# description already exists
# alias already exists
# Q124691957
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21399050'}}]
# description already exists
# alias already exists
# Q21399050
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691963'}}]
# description already exists
# alias already exists
# Q124691963
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691968'}}]
# description already exists
# alias already exists
# Q124691968
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397646'}}]
# description already exists
# alias already exists
# Q21397646
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691975'}}]
# description already exists
# alias already exists
# Q124691975
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691981'}}]
# description already exists
# alias already exists
# Q124691981
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691985'}}]
# description already exists
# alias already exists
# Q124691985
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691990'}}]
# description already exists
# alias already exists
# Q124691990
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691993'}}]
# description already exists
# alias already exists
# Q124691993
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691997'}}]
# description already exists
# alias already exists
# Q124691997
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692001'}}]
# description already exists
# alias already exists
# Q124692001
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21399182'}}]
# description already exists
# alias already exists
# Q21399182
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692007'}}]
# description already exists
# alias already exists
# Q124692007
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692009'}}]
# description already exists
# alias already exists
# Q124692009
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692012'}}]
# description already exists
# alias already exists
# Q124692012
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692015'}}]
# description already exists
# alias already exists
# Q124692015
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692020'}}]
# description already exists
# alias already exists
# Q124692020
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692025'}}]
# description already exists
# alias already exists
# Q124692025
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692029'}}]
# description already exists
# alias already exists
# Q124692029
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398909'}}]
# description already exists
# alias already exists
# Q21398909
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398909'}}]
# description already exists
# alias already exists
# Q21398909
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124692025'}}]
# description already exists
# alias already exists
# Q124692025
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398974'}}]
# description already exists
# alias already exists
# Q21398974
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124694979'}}]
# description already exists
# alias already exists
# Q124694979
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695071'}}]
# description already exists
# alias already exists
# Q124695071
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124664454'}}]
# description already exists
# alias already exists
# Q124664454
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21384655'}}]
# description already exists
# alias already exists
# Q21384655
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21384649'}}]
# description already exists
# alias already exists
# Q21384649
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695222'}}]
# description already exists
# alias already exists
# Q124695222
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695367'}}]
# description already exists
# alias already exists
# Q124695367
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695442'}}]
# description already exists
# alias already exists
# Q124695442
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695818'}}]
# description already exists
# alias already exists
# Q124695818
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21382032'}}]
# description already exists
# alias already exists
# Q21382032
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21399437'}}]
# description already exists
# alias already exists
# Q21399437
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691743'}}]
# description already exists
# alias already exists
# Q124691743
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102975'}}]
# description already exists
# alias already exists
# Q21102975
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695841'}}]
# description already exists
# alias already exists
# Q124695841
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695853'}}]
# description already exists
# alias already exists
# Q124695853
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695871'}}]
# description already exists
# alias already exists
# Q124695871
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695898'}}]
# description already exists
# alias already exists
# Q124695898
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695937'}}]
# description already exists
# alias already exists
# Q124695937
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695963'}}]
# description already exists
# alias already exists
# Q124695963
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21399185'}}]
# description already exists
# alias already exists
# Q21399185
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695987'}}]
# description already exists
# alias already exists
# Q124695987
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398532'}}]
# description already exists
# alias already exists
# Q21398532
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398310'}}]
# description already exists
# alias already exists
# Q21398310
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695898'}}]
# description already exists
# alias already exists
# Q124695898
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124696030'}}]
# description already exists
# alias already exists
# Q124696030
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124696057'}}]
# description already exists
# alias already exists
# Q124696057
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124696092'}}]
# description already exists
# alias already exists
# Q124696092
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124696112'}}]
# description already exists
# alias already exists
# Q124696112
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124696372'}}]
# description already exists
# alias already exists
# Q124696372
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124696753'}}]
# description already exists
# alias already exists
# Q124696753
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124697118'}}]
# description already exists
# alias already exists
# Q124697118
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124697479'}}]
# description already exists
# alias already exists
# Q124697479
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102981'}}]
# description already exists
# alias already exists
# Q21102981
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124697705'}}]
# description already exists
# alias already exists
# Q124697705
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124697731'}}]
# description already exists
# alias already exists
# Q124697731
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102965'}}]
# description already exists
# alias already exists
# Q21102965
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124697771'}}]
# description already exists
# alias already exists
# Q124697771
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21384655'}}]
# description already exists
# alias already exists
# Q21384655
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124697946'}}]
# description already exists
# alias already exists
# Q124697946
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124698306'}}]
# description already exists
# alias already exists
# Q124698306
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124698678'}}]
# description already exists
# alias already exists
# Q124698678
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21384654'}}]
# description already exists
# alias already exists
# Q21384654
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397910'}}]
# description already exists
# alias already exists
# Q21397910
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124699132'}}]
# description already exists
# alias already exists
# Q124699132
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124703915'}}]
# description already exists
# alias already exists
# Q124703915
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28974562'}}]
# description already exists
# alias already exists
# Q28974562
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124703931'}}]
# description already exists
# alias already exists
# Q124703931
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124703948'}}]
# description already exists
# alias already exists
# Q124703948
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124699132'}}]
# description already exists
# alias already exists
# Q124699132
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695222'}}]
# description already exists
# alias already exists
# Q124695222
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124703971'}}]
# description already exists
# alias already exists
# Q124703971
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124703992'}}]
# description already exists
# alias already exists
# Q124703992
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102965'}}]
# description already exists
# alias already exists
# Q21102965
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124691429'}}]
# description already exists
# alias already exists
# Q124691429
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704013'}}]
# description already exists
# alias already exists
# Q124704013
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398305'}}]
# description already exists
# alias already exists
# Q21398305
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704037'}}]
# description already exists
# alias already exists
# Q124704037
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695818'}}]
# description already exists
# alias already exists
# Q124695818
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695898'}}]
# description already exists
# alias already exists
# Q124695898
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21384650'}}]
# description already exists
# alias already exists
# Q21384650
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21384651'}}]
# description already exists
# alias already exists
# Q21384651
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695222'}}]
# description already exists
# alias already exists
# Q124695222
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704055'}}]
# description already exists
# alias already exists
# Q124704055
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124698306'}}]
# description already exists
# alias already exists
# Q124698306
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704100'}}]
# description already exists
# alias already exists
# Q124704100
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704258'}}]
# description already exists
# alias already exists
# Q124704258
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124695987'}}]
# description already exists
# alias already exists
# Q124695987
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704055'}}]
# description already exists
# alias already exists
# Q124704055
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21382941'}}]
# description already exists
# alias already exists
# Q21382941
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102960'}}]
# description already exists
# alias already exists
# Q21102960
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21398118'}}]
# description already exists
# alias already exists
# Q21398118
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704642'}}]
# description already exists
# alias already exists
# Q124704642
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704659'}}]
# description already exists
# alias already exists
# Q124704659
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704669'}}]
# description already exists
# alias already exists
# Q124704669
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704669'}}]
# description already exists
# alias already exists
# Q124704669
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704682'}}]
# description already exists
# alias already exists
# Q124704682
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704696'}}]
# description already exists
# alias already exists
# Q124704696
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397972'}}]
# description already exists
# alias already exists
# Q21397972
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397972'}}]
# description already exists
# alias already exists
# Q21397972
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397972'}}]
# description already exists
# alias already exists
# Q21397972
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21397972'}}]
# description already exists
# alias already exists
# Q21397972
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704669'}}]
# description already exists
# alias already exists
# Q124704669
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704709'}}]
# description already exists
# alias already exists
# Q124704709
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21102981'}}]
# description already exists
# alias already exists
# Q21102981
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124663344'}}]
# description already exists
# alias already exists
# Q124663344
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q21399259'}}]
# description already exists
# alias already exists
# Q21399259
# claim already existent
# claim already existent

# %%
df[["genbank_start", "genbank_stop", "refseq_gene", "gene_family", "strain_wd_id"]]
# Out:
#       genbank_start  genbank_stop  \
# 0           7204881       7205417
# 2                 1           723
# 4               373           918
# 20          2333620       2334096
# 21           638262        638720
# ...             ...           ...
# 5562        1776505       1777113
# 5614              1           633
# 5626          66031         67602
# 5628              1           891
# 5630         878482        879282
#
#                                          refseq_gene      gene_family  \
# 0     Pseudomonas aeruginosa PA38182 aac(2')-I(A267)  aac(2')-I(A267)
# 2                Paenibacillus sp. LC231 aac(2')-IIb      aac(2')-IIb
# 4        Mycobacterium tuberculosis H37Rv aac(2')-Ic       aac(2')-Ic
# 20           Saccharophagus degradans 2-40 aac(3)-Ig        aac(3)-Ig
# 21          Sphingopyxis alaskensis RB2256 aac(3)-Ii        aac(3)-Ii
# ...                                              ...              ...
# 5562       Desulfitobacterium hafniense DCB-2 vanX-I           vanX-I
# 5614                    Paenibacillus sp. LC231 vatI             vatI
# 5626             Listeria monocytogenes EGD-e vga(G)           vga(G)
# 5628                    Paenibacillus sp. LC231 vgbC             vgbC
# 5630                               Streptococcus pyo             folP
#
#      strain_wd_id
# 0      Q124664031
# 2      Q124663344
# 4       Q21102987
# 20      Q21398890
# 21      Q21398562
# ...           ...
# 5562   Q124704709
# 5614   Q124663344
# 5626    Q21102981
# 5628   Q124663344
# 5630    Q21399259
#
# [312 rows x 5 columns]

# %%
# Including gene into wikidata -- Entrez Gene ID is missing here 

from WikidataAdder import GeneWikidataAdder


def gene_wrapper(df_row: pd.Series) -> str | None: 
    gwa = GeneWikidataAdder(df_row, False)
    success = gwa.create_gene()
    if success:
        gwa.add_instance_of_gene()
        gwa.add_subclass_of()
        gwa.add_found_in_taxon()
        return gwa.gene_page.getID()
    return None

# %%
df["wd_gene_id"] = df.apply(gene_wrapper, axis=1)
# Out:
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124678817'}}]
# description already exists
# Q124678817
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124683975'}}]
# description already exists
# Q124683975
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704728'}}]
# description already exists
# Q124704728
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704731'}}]
# description already exists
# Q124704731
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704734'}}]
# description already exists
# Q124704734
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704740'}}]
# description already exists
# Q124704740
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704742'}}]
# description already exists
# Q124704742
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704744'}}]
# description already exists
# Q124704744
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704750'}}]
# description already exists
# Q124704750
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704753'}}]
# description already exists
# Q124704753
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704760'}}]
# description already exists
# Q124704760
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704778'}}]
# description already exists
# Q124704778
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704787'}}]
# description already exists
# Q124704787
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704791'}}]
# description already exists
# Q124704791
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704801'}}]
# description already exists
# Q124704801
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704804'}}]
# description already exists
# Q124704804
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704810'}}]
# description already exists
# Q124704810
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704814'}}]
# description already exists
# Q124704814
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704821'}}]
# description already exists
# Q124704821
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704825'}}]
# description already exists
# Q124704825
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704828'}}]
# description already exists
# Q124704828
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704836'}}]
# description already exists
# Q124704836
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704838'}}]
# description already exists
# Q124704838
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704841'}}]
# description already exists
# Q124704841
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704845'}}]
# description already exists
# Q124704845
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704848'}}]
# description already exists
# Q124704848
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704855'}}]
# description already exists
# Q124704855
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704862'}}]
# description already exists
# Q124704862
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704867'}}]
# description already exists
# Q124704867
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704871'}}]
# description already exists
# Q124704871
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704874'}}]
# description already exists
# Q124704874
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704876'}}]
# description already exists
# Q124704876
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704879'}}]
# description already exists
# Q124704879
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704881'}}]
# description already exists
# Q124704881
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704884'}}]
# description already exists
# Q124704884
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704887'}}]
# description already exists
# Q124704887
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704890'}}]
# description already exists
# Q124704890
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704893'}}]
# description already exists
# Q124704893
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704898'}}]
# description already exists
# Q124704898
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704900'}}]
# description already exists
# Q124704900
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704905'}}]
# description already exists
# Q124704905
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704909'}}]
# description already exists
# Q124704909
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704912'}}]
# description already exists
# Q124704912
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704919'}}]
# description already exists
# Q124704919
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704923'}}]
# description already exists
# Q124704923
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704925'}}]
# description already exists
# Q124704925
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704928'}}]
# description already exists
# Q124704928
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704933'}}]
# description already exists
# Q124704933
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704937'}}]
# description already exists
# Q124704937
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704940'}}]
# description already exists
# Q124704940
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704946'}}]
# description already exists
# Q124704946
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704949'}}]
# description already exists
# Q124704949
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704955'}}]
# description already exists
# Q124704955
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704958'}}]
# description already exists
# Q124704958
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704963'}}]
# description already exists
# Q124704963
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704970'}}]
# description already exists
# Q124704970
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704985'}}]
# description already exists
# Q124704985
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704989'}}]
# description already exists
# Q124704989
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704994'}}]
# description already exists
# Q124704994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704996'}}]
# description already exists
# Q124704996
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124704999'}}]
# description already exists
# Q124704999
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705005'}}]
# description already exists
# Q124705005
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705010'}}]
# description already exists
# Q124705010
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705016'}}]
# description already exists
# Q124705016
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705019'}}]
# description already exists
# Q124705019
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705021'}}]
# description already exists
# Q124705021
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705024'}}]
# description already exists
# Q124705024
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705026'}}]
# description already exists
# Q124705026
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705031'}}]
# description already exists
# Q124705031
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705035'}}]
# description already exists
# Q124705035
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705048'}}]
# description already exists
# Q124705048
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705062'}}]
# description already exists
# Q124705062
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705068'}}]
# description already exists
# Q124705068
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705070'}}]
# description already exists
# Q124705070
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705073'}}]
# description already exists
# Q124705073
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705076'}}]
# description already exists
# Q124705076
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705084'}}]
# description already exists
# Q124705084
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705088'}}]
# description already exists
# Q124705088
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705094'}}]
# description already exists
# Q124705094
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705097'}}]
# description already exists
# Q124705097
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705102'}}]
# description already exists
# Q124705102
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705107'}}]
# description already exists
# Q124705107
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705109'}}]
# description already exists
# Q124705109
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705112'}}]
# description already exists
# Q124705112
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705115'}}]
# description already exists
# Q124705115
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705119'}}]
# description already exists
# Q124705119
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705123'}}]
# description already exists
# Q124705123
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705127'}}]
# description already exists
# Q124705127
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705130'}}]
# description already exists
# Q124705130
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705131'}}]
# description already exists
# Q124705131
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705134'}}]
# description already exists
# Q124705134
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705136'}}]
# description already exists
# Q124705136
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705138'}}]
# description already exists
# Q124705138
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705140'}}]
# description already exists
# Q124705140
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705143'}}]
# description already exists
# Q124705143
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705145'}}]
# description already exists
# Q124705145
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705147'}}]
# description already exists
# Q124705147
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705151'}}]
# description already exists
# Q124705151
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705154'}}]
# description already exists
# Q124705154
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705157'}}]
# description already exists
# Q124705157
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705162'}}]
# description already exists
# Q124705162
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705190'}}]
# description already exists
# Q124705190
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705192'}}]
# description already exists
# Q124705192
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705221'}}]
# description already exists
# Q124705221
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705282'}}]
# description already exists
# Q124705282
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705347'}}]
# description already exists
# Q124705347
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705424'}}]
# description already exists
# Q124705424
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705491'}}]
# description already exists
# Q124705491
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705540'}}]
# description already exists
# Q124705540
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705543'}}]
# description already exists
# Q124705543
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705545'}}]
# description already exists
# Q124705545
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705547'}}]
# description already exists
# Q124705547
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705549'}}]
# description already exists
# Q124705549
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705553'}}]
# description already exists
# Q124705553
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705559'}}]
# description already exists
# Q124705559
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705562'}}]
# description already exists
# Q124705562
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705565'}}]
# description already exists
# Q124705565
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705569'}}]
# description already exists
# Q124705569
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705575'}}]
# description already exists
# Q124705575
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705580'}}]
# description already exists
# Q124705580
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705583'}}]
# description already exists
# Q124705583
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705589'}}]
# description already exists
# Q124705589
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705601'}}]
# description already exists
# Q124705601
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705607'}}]
# description already exists
# Q124705607
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705610'}}]
# description already exists
# Q124705610
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705630'}}]
# description already exists
# Q124705630
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705643'}}]
# description already exists
# Q124705643
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705646'}}]
# description already exists
# Q124705646
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705687'}}]
# description already exists
# Q124705687
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705691'}}]
# description already exists
# Q124705691
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705713'}}]
# description already exists
# Q124705713
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705721'}}]
# description already exists
# Q124705721
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705726'}}]
# description already exists
# Q124705726
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705730'}}]
# description already exists
# Q124705730
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705733'}}]
# description already exists
# Q124705733
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705739'}}]
# description already exists
# Q124705739
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705741'}}]
# description already exists
# Q124705741
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705744'}}]
# description already exists
# Q124705744
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705749'}}]
# description already exists
# Q124705749
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705752'}}]
# description already exists
# Q124705752
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705758'}}]
# description already exists
# Q124705758
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705760'}}]
# description already exists
# Q124705760
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705764'}}]
# description already exists
# Q124705764
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705766'}}]
# description already exists
# Q124705766
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705770'}}]
# description already exists
# Q124705770
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705772'}}]
# description already exists
# Q124705772
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705775'}}]
# description already exists
# Q124705775
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705778'}}]
# description already exists
# Q124705778
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705782'}}]
# description already exists
# Q124705782
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705783'}}]
# description already exists
# Q124705783
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705786'}}]
# description already exists
# Q124705786
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705789'}}]
# description already exists
# Q124705789
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705794'}}]
# description already exists
# Q124705794
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705797'}}]
# description already exists
# Q124705797
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705799'}}]
# description already exists
# Q124705799
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705802'}}]
# description already exists
# Q124705802
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705808'}}]
# description already exists
# Q124705808
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705810'}}]
# description already exists
# Q124705810
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705812'}}]
# description already exists
# Q124705812
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705814'}}]
# description already exists
# Q124705814
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705817'}}]
# description already exists
# Q124705817
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705820'}}]
# description already exists
# Q124705820
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705826'}}]
# description already exists
# Q124705826
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705828'}}]
# description already exists
# Q124705828
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705830'}}]
# description already exists
# Q124705830
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705832'}}]
# description already exists
# Q124705832
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705836'}}]
# description already exists
# Q124705836
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705840'}}]
# description already exists
# Q124705840
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705843'}}]
# description already exists
# Q124705843
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705847'}}]
# description already exists
# Q124705847
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705850'}}]
# description already exists
# Q124705850
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705853'}}]
# description already exists
# Q124705853
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705855'}}]
# description already exists
# Q124705855
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705858'}}]
# description already exists
# Q124705858
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705859'}}]
# description already exists
# Q124705859
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705863'}}]
# description already exists
# Q124705863
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705865'}}]
# description already exists
# Q124705865
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705867'}}]
# description already exists
# Q124705867
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705871'}}]
# description already exists
# Q124705871
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705875'}}]
# description already exists
# Q124705875
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705876'}}]
# description already exists
# Q124705876
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705878'}}]
# description already exists
# Q124705878
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705882'}}]
# description already exists
# Q124705882
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705885'}}]
# description already exists
# Q124705885
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705888'}}]
# description already exists
# Q124705888
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705890'}}]
# description already exists
# Q124705890
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705893'}}]
# description already exists
# Q124705893
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705895'}}]
# description already exists
# Q124705895
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705897'}}]
# description already exists
# Q124705897
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705904'}}]
# description already exists
# Q124705904
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705925'}}]
# description already exists
# Q124705925
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705933'}}]
# description already exists
# Q124705933
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705936'}}]
# description already exists
# Q124705936
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705944'}}]
# description already exists
# Q124705944
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705948'}}]
# description already exists
# Q124705948
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705953'}}]
# description already exists
# Q124705953
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705955'}}]
# description already exists
# Q124705955
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705961'}}]
# description already exists
# Q124705961
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705964'}}]
# description already exists
# Q124705964
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705965'}}]
# description already exists
# Q124705965
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705969'}}]
# description already exists
# Q124705969
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705972'}}]
# description already exists
# Q124705972
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705974'}}]
# description already exists
# Q124705974
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705976'}}]
# description already exists
# Q124705976
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705980'}}]
# description already exists
# Q124705980
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705982'}}]
# description already exists
# Q124705982
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705984'}}]
# description already exists
# Q124705984
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705986'}}]
# description already exists
# Q124705986
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705988'}}]
# description already exists
# Q124705988
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705990'}}]
# description already exists
# Q124705990
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705991'}}]
# description already exists
# Q124705991
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705994'}}]
# description already exists
# Q124705994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124705996'}}]
# description already exists
# Q124705996
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124706000'}}]
# description already exists
# Q124706000
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124706002'}}]
# description already exists
# Q124706002
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124706004'}}]
# description already exists
# Q124706004
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707059'}}]
# description already exists
# Q124707059
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707062'}}]
# description already exists
# Q124707062
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707064'}}]
# description already exists
# Q124707064
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707068'}}]
# description already exists
# Q124707068
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707073'}}]
# description already exists
# Q124707073
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707077'}}]
# description already exists
# Q124707077
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707085'}}]
# description already exists
# Q124707085
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707088'}}]
# description already exists
# Q124707088
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707091'}}]
# description already exists
# Q124707091
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707095'}}]
# description already exists
# Q124707095
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707098'}}]
# ...
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707138'}}]
# description already exists
# Q124707138
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707141'}}]
# description already exists
# Q124707141
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707144'}}]
# description already exists
# Q124707144
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707149'}}]
# description already exists
# Q124707149
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707152'}}]
# description already exists
# Q124707152
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707157'}}]
# description already exists
# Q124707157
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707163'}}]
# description already exists
# Q124707163
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707173'}}]
# description already exists
# Q124707173
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707186'}}]
# description already exists
# Q124707186
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707201'}}]
# description already exists
# Q124707201
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707212'}}]
# description already exists
# Q124707212
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707225'}}]
# description already exists
# Q124707225
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707238'}}]
# description already exists
# Q124707238
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707249'}}]
# description already exists
# Q124707249
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707265'}}]
# description already exists
# Q124707265
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707280'}}]
# description already exists
# Q124707280
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707300'}}]
# description already exists
# Q124707300
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707314'}}]
# description already exists
# Q124707314
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707329'}}]
# description already exists
# Q124707329
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707340'}}]
# description already exists
# Q124707340
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707347'}}]
# description already exists
# Q124707347
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707349'}}]
# description already exists
# Q124707349
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707352'}}]
# description already exists
# Q124707352
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707354'}}]
# description already exists
# Q124707354
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707356'}}]
# description already exists
# Q124707356
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707357'}}]
# description already exists
# Q124707357
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707360'}}]
# description already exists
# Q124707360
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707362'}}]
# description already exists
# Q124707362
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707367'}}]
# description already exists
# Q124707367
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707371'}}]
# description already exists
# Q124707371
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707374'}}]
# description already exists
# Q124707374
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707381'}}]
# description already exists
# Q124707381
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707385'}}]
# description already exists
# Q124707385
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707388'}}]
# description already exists
# Q124707388
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707390'}}]
# description already exists
# Q124707390
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707393'}}]
# description already exists
# Q124707393
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707396'}}]
# description already exists
# Q124707396
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707398'}}]
# description already exists
# Q124707398
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707412'}}]
# description already exists
# Q124707412
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707415'}}]
# description already exists
# Q124707415
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707421'}}]
# description already exists
# Q124707421
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707424'}}]
# description already exists
# Q124707424
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707428'}}]
# description already exists
# Q124707428
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707431'}}]
# description already exists
# Q124707431
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707434'}}]
# description already exists
# Q124707434
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707436'}}]
# description already exists
# Q124707436
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707439'}}]
# description already exists
# Q124707439
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707442'}}]
# description already exists
# Q124707442
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707445'}}]
# description already exists
# Q124707445
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707446'}}]
# description already exists
# Q124707446
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707448'}}]
# description already exists
# Q124707448
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707452'}}]
# description already exists
# Q124707452
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707453'}}]
# description already exists
# Q124707453
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707457'}}]
# description already exists
# Q124707457
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707459'}}]
# description already exists
# Q124707459
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707462'}}]
# description already exists
# Q124707462
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707463'}}]
# description already exists
# Q124707463
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707467'}}]
# description already exists
# Q124707467
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707471'}}]
# description already exists
# Q124707471
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707474'}}]
# description already exists
# Q124707474
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707476'}}]
# description already exists
# Q124707476
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707480'}}]
# description already exists
# Q124707480
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707484'}}]
# description already exists
# Q124707484
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707488'}}]
# description already exists
# Q124707488
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707489'}}]
# description already exists
# Q124707489
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707491'}}]
# description already exists
# Q124707491
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707492'}}]
# description already exists
# Q124707492
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707493'}}]
# description already exists
# Q124707493
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707495'}}]
# description already exists
# Q124707495
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707497'}}]
# description already exists
# Q124707497
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707499'}}]
# description already exists
# Q124707499
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707502'}}]
# description already exists
# Q124707502
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707504'}}]
# description already exists
# Q124707504
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707507'}}]
# description already exists
# Q124707507
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707518'}}]
# description already exists
# Q124707518
# claim already existent
# claim already existent
# claim already existent
# claim already existent

# %%
# Including Protein into wikidata -- some proteins are encoded by the same bacterial strain 
# Thats why some proteins have multiple "found in taxon" Qualifiers 

from WikidataAdder import ProteinWikidataAdder

def protein_wrapper(df_row: pd.Series) -> str | None: 
    pwa = ProteinWikidataAdder(df_row, False)
    created = pwa.create_protein()
    if created != 0:
        pwa.add_instance_of()
        pwa.add_subclass_of()
        pwa.add_found_in_taxon()
        pwa.add_encoded_by()
        pwa.add_identifier()
        pwa.add_antibiotic_resistance()
        if created == 2: 
            print("wait after creation")
            time.sleep(300)
        return pwa.protein_page.getID()
    return None

# %%
df["wd_protein_id"] = df.apply(protein_wrapper, axis=1)
# Out:
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124683955'}}]
# description already exists
# Q124683955
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124683978'}}]
# description already exists
# Q124683978
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707533'}}]
# description already exists
# Q124707533
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707538'}}]
# description already exists
# Q124707538
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707586'}}]
# description already exists
# Q124707586
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# description already exists
# Q124707638
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Q124707638
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.3 seconds, 2024-03-03 20:55:13
# Q124707638
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.3 seconds, 2024-03-03 20:55:23
# Q124707638
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:55:33
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.6 seconds, 2024-03-03 20:55:43
# Sleeping for 9.6 seconds, 2024-03-03 20:55:53
# Sleeping for 9.6 seconds, 2024-03-03 20:56:03
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:56:13
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 20:56:23
# Sleeping for 9.4 seconds, 2024-03-03 20:56:33
# Sleeping for 9.6 seconds, 2024-03-03 20:56:43
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:56:53
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 20:57:03
# Sleeping for 9.5 seconds, 2024-03-03 20:57:13
# Sleeping for 9.6 seconds, 2024-03-03 20:57:23
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:57:33
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.6 seconds, 2024-03-03 20:57:43
# Sleeping for 9.6 seconds, 2024-03-03 20:57:53
# Sleeping for 9.6 seconds, 2024-03-03 20:58:03
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:58:13
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 20:58:23
# Sleeping for 9.6 seconds, 2024-03-03 20:58:33
# Sleeping for 9.6 seconds, 2024-03-03 20:58:43
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:58:53
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.6 seconds, 2024-03-03 20:59:03
# Sleeping for 9.6 seconds, 2024-03-03 20:59:13
# Sleeping for 9.6 seconds, 2024-03-03 20:59:23
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 20:59:33
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 20:59:43
# Sleeping for 9.6 seconds, 2024-03-03 20:59:53
# Sleeping for 9.6 seconds, 2024-03-03 21:00:03
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:00:14
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:00:23
# Sleeping for 9.5 seconds, 2024-03-03 21:00:33
# Sleeping for 9.6 seconds, 2024-03-03 21:00:43
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:00:54
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:01:03
# Sleeping for 9.5 seconds, 2024-03-03 21:01:13
# Sleeping for 9.6 seconds, 2024-03-03 21:01:23
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707694'}}]
# description already exists
# Q124707694
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707698'}}]
# description already exists
# Q124707698
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707700'}}]
# description already exists
# Q124707700
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707703'}}]
# description already exists
# Q124707703
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707710'}}]
# description already exists
# Q124707710
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707716'}}]
# description already exists
# Q124707716
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707716'}}]
# Sleeping for 6.3 seconds, 2024-03-03 21:01:37
# Q124707716
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:01:43
# Sleeping for 9.4 seconds, 2024-03-03 21:01:53
# Sleeping for 9.6 seconds, 2024-03-03 21:02:03
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707716'}}]
# Sleeping for 9.3 seconds, 2024-03-03 21:02:14
# Q124707716
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:02:23
# Sleeping for 9.6 seconds, 2024-03-03 21:02:33
# Sleeping for 9.6 seconds, 2024-03-03 21:02:43
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707716'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:02:54
# Q124707716
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707716'}}]
# Sleeping for 9.3 seconds, 2024-03-03 21:03:04
# Q124707716
# claim already existent
# claim already existent
# Sleeping for 9.6 seconds, 2024-03-03 21:03:13
# Sleeping for 9.5 seconds, 2024-03-03 21:03:23
# Sleeping for 9.5 seconds, 2024-03-03 21:03:33
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:03:44
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:03:54
# Sleeping for 9.6 seconds, 2024-03-03 21:04:03
# Sleeping for 9.5 seconds, 2024-03-03 21:04:13
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:04:24
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:04:34
# Sleeping for 9.6 seconds, 2024-03-03 21:04:43
# Sleeping for 9.5 seconds, 2024-03-03 21:04:53
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:05:04
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:05:14
# Sleeping for 9.6 seconds, 2024-03-03 21:05:23
# Sleeping for 9.5 seconds, 2024-03-03 21:05:34
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.0 seconds, 2024-03-03 21:05:44
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:05:54
# Sleeping for 9.5 seconds, 2024-03-03 21:06:04
# Sleeping for 9.5 seconds, 2024-03-03 21:06:14
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:06:24
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:06:34
# Sleeping for 9.6 seconds, 2024-03-03 21:06:44
# Sleeping for 9.5 seconds, 2024-03-03 21:06:54
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.0 seconds, 2024-03-03 21:07:04
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:07:14
# Sleeping for 9.6 seconds, 2024-03-03 21:07:24
# Sleeping for 9.4 seconds, 2024-03-03 21:07:34
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:07:44
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:07:54
# Sleeping for 9.6 seconds, 2024-03-03 21:08:04
# Sleeping for 9.6 seconds, 2024-03-03 21:08:14
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:08:24
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:08:34
# Sleeping for 9.6 seconds, 2024-03-03 21:08:44
# Sleeping for 9.5 seconds, 2024-03-03 21:08:54
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:09:04
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:09:14
# Sleeping for 9.5 seconds, 2024-03-03 21:09:24
# Sleeping for 9.5 seconds, 2024-03-03 21:09:34
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:09:44
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:09:54
# Sleeping for 9.6 seconds, 2024-03-03 21:10:04
# Sleeping for 9.2 seconds, 2024-03-03 21:10:14
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:10:24
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:10:34
# Sleeping for 9.5 seconds, 2024-03-03 21:10:44
# Sleeping for 9.5 seconds, 2024-03-03 21:10:54
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.0 seconds, 2024-03-03 21:11:04
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:11:14
# Sleeping for 9.6 seconds, 2024-03-03 21:11:24
# Sleeping for 9.5 seconds, 2024-03-03 21:11:34
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:11:44
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:11:54
# Sleeping for 9.5 seconds, 2024-03-03 21:12:04
# Sleeping for 9.4 seconds, 2024-03-03 21:12:14
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:12:24
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:12:34
# Sleeping for 9.6 seconds, 2024-03-03 21:12:44
# Sleeping for 9.4 seconds, 2024-03-03 21:12:54
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:13:04
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.4 seconds, 2024-03-03 21:13:14
# Sleeping for 9.6 seconds, 2024-03-03 21:13:24
# Sleeping for 9.5 seconds, 2024-03-03 21:13:34
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707638'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:13:44
# Q124707638
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:13:54
# Sleeping for 9.5 seconds, 2024-03-03 21:14:04
# Sleeping for 9.4 seconds, 2024-03-03 21:14:14
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707729'}}]
# description already exists
# Q124707729
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707734'}}]
# description already exists
# Q124707734
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707734'}}]
# Sleeping for 8.2 seconds, 2024-03-03 21:14:25
# Q124707734
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707734'}}]
# Sleeping for 8.9 seconds, 2024-03-03 21:14:35
# Q124707734
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707743'}}]
# description already exists
# Q124707743
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707745'}}]
# description already exists
# Q124707745
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707745'}}]
# Sleeping for 8.4 seconds, 2024-03-03 21:14:45
# Q124707745
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707752'}}]
# description already exists
# Q124707752
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707755'}}]
# description already exists
# Q124707755
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707756'}}]
# description already exists
# Q124707756
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707757'}}]
# description already exists
# Q124707757
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707757'}}]
# Sleeping for 7.5 seconds, 2024-03-03 21:14:56
# Q124707757
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:15:04
# Sleeping for 9.5 seconds, 2024-03-03 21:15:14
# Sleeping for 9.6 seconds, 2024-03-03 21:15:24
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707761'}}]
# description already exists
# Q124707761
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707764'}}]
# description already exists
# Q124707764
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707764'}}]
# Sleeping for 8.3 seconds, 2024-03-03 21:15:35
# Q124707764
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:15:44
# Sleeping for 9.3 seconds, 2024-03-03 21:15:54
# Sleeping for 9.6 seconds, 2024-03-03 21:16:04
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707764'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:16:14
# Q124707764
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:16:24
# Sleeping for 9.6 seconds, 2024-03-03 21:16:34
# Sleeping for 9.5 seconds, 2024-03-03 21:16:44
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707764'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:16:54
# Q124707764
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:17:04
# Sleeping for 9.6 seconds, 2024-03-03 21:17:14
# Sleeping for 9.5 seconds, 2024-03-03 21:17:24
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707764'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:17:35
# Q124707764
# claim already existent
# claim already existent
# Sleeping for 9.6 seconds, 2024-03-03 21:17:44
# Sleeping for 9.3 seconds, 2024-03-03 21:17:54
# Sleeping for 9.5 seconds, 2024-03-03 21:18:04
# ERROR: Traceback (most recent call last):
#   File "/home/finn/Documents/python-venvs/lodkg/lib/python3.10/site-packages/pywikibot/data/api/_requests.py", line 682, in _http_request
#     response = http.request(self.site, uri=uri,
#   File "/home/finn/Documents/python-venvs/lodkg/lib/python3.10/site-packages/pywikibot/comms/http.py", line 283, in request
#     r = fetch(baseuri, headers=headers, **kwargs)
#   File "/home/finn/Documents/python-venvs/lodkg/lib/python3.10/site-packages/pywikibot/comms/http.py", line 457, in fetch
#     callback(response)
#   File "/home/finn/Documents/python-venvs/lodkg/lib/python3.10/site-packages/pywikibot/comms/http.py", line 333, in error_handling_callback
#     raise ServerError(response)
# pywikibot.exceptions.ServerError: HTTPSConnectionPool(host='www.wikidata.org', port=443): Read timed out. (read timeout=45)
#
# WARNING: Waiting 5.0 seconds before retrying.
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707791'}}]
# description already exists
# Q124707791
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707791'}}]
# Sleeping for 7.9 seconds, 2024-03-03 21:35:41
# Q124707791
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:35:49
# Sleeping for 9.4 seconds, 2024-03-03 21:35:59
# Sleeping for 9.6 seconds, 2024-03-03 21:36:09
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707791'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:36:20
# Q124707791
# claim already existent
# claim already existent
# Sleeping for 9.6 seconds, 2024-03-03 21:36:29
# Sleeping for 9.6 seconds, 2024-03-03 21:36:39
# Sleeping for 9.6 seconds, 2024-03-03 21:36:49
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707800'}}]
# description already exists
# Q124707800
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707800'}}]
# Sleeping for 8.2 seconds, 2024-03-03 21:37:01
# Q124707800
# claim already existent
# claim already existent
# Sleeping for 9.5 seconds, 2024-03-03 21:37:09
# Sleeping for 9.5 seconds, 2024-03-03 21:37:19
# Sleeping for 9.6 seconds, 2024-03-03 21:37:29
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707810'}}]
# description already exists
# Q124707810
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707822'}}]
# description already exists
# Q124707822
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707827'}}]
# description already exists
# Q124707827
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707829'}}]
# description already exists
# Q124707829
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707831'}}]
# description already exists
# Q124707831
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707834'}}]
# description already exists
# Q124707834
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707847'}}]
# description already exists
# Q124707847
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707864'}}]
# description already exists
# Q124707864
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707867'}}]
# description already exists
# Q124707867
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707871'}}]
# description already exists
# Q124707871
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707873'}}]
# description already exists
# Q124707873
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707876'}}]
# description already exists
# Q124707876
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707881'}}]
# description already exists
# Q124707881
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707884'}}]
# description already exists
# Q124707884
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707889'}}]
# description already exists
# Q124707889
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707893'}}]
# description already exists
# Q124707893
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707895'}}]
# description already exists
# Q124707895
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707900'}}]
# description already exists
# Q124707900
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124707903'}}]
# description already exists
# Q124707903
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711852'}}]
# description already exists
# Q124711852
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711854'}}]
# description already exists
# Q124711854
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711859'}}]
# description already exists
# Q124711859
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711882'}}]
# description already exists
# Q124711882
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711886'}}]
# description already exists
# Q124711886
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711902'}}]
# description already exists
# Q124711902
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711905'}}]
# description already exists
# Q124711905
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711908'}}]
# description already exists
# Q124711908
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711914'}}]
# description already exists
# Q124711914
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711936'}}]
# description already exists
# Q124711936
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711944'}}]
# description already exists
# Q124711944
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711950'}}]
# description already exists
# Q124711950
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711973'}}]
# description already exists
# Q124711973
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711979'}}]
# description already exists
# Q124711979
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124711984'}}]
# description already exists
# Q124711984
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712007'}}]
# description already exists
# Q124712007
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712019'}}]
# description already exists
# Q124712019
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712026'}}]
# description already exists
# Q124712026
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712036'}}]
# description already exists
# Q124712036
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712038'}}]
# description already exists
# Q124712038
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712161'}}]
# description already exists
# Q124712161
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712454'}}]
# description already exists
# Q124712454
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712781'}}]
# description already exists
# Q124712781
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712967'}}]
# description already exists
# Q124712967
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712976'}}]
# description already exists
# Q124712976
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712986'}}]
# description already exists
# Q124712986
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712993'}}]
# description already exists
# Q124712993
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124712998'}}]
# description already exists
# Q124712998
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713012'}}]
# description already exists
# Q124713012
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713023'}}]
# description already exists
# Q124713023
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713047'}}]
# description already exists
# Q124713047
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713056'}}]
# description already exists
# Q124713056
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713071'}}]
# description already exists
# Q124713071
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713092'}}]
# description already exists
# Q124713092
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713110'}}]
# description already exists
# Q124713110
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713140'}}]
# description already exists
# Q124713140
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713159'}}]
# description already exists
# Q124713159
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713189'}}]
# description already exists
# Q124713189
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713203'}}]
# description already exists
# Q124713203
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713219'}}]
# description already exists
# Q124713219
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713250'}}]
# description already exists
# Q124713250
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713266'}}]
# description already exists
# Q124713266
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713279'}}]
# description already exists
# Q124713279
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713296'}}]
# description already exists
# Q124713296
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713318'}}]
# description already exists
# Q124713318
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713339'}}]
# description already exists
# Q124713339
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713353'}}]
# description already exists
# Q124713353
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713367'}}]
# description already exists
# Q124713367
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713373'}}]
# description already exists
# Q124713373
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713402'}}]
# description already exists
# Q124713402
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713417'}}]
# description already exists
# Q124713417
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713432'}}]
# description already exists
# Q124713432
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713458'}}]
# description already exists
# Q124713458
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713539'}}]
# description already exists
# Q124713539
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713547'}}]
# description already exists
# Q124713547
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713562'}}]
# description already exists
# Q124713562
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713582'}}]
# description already exists
# Q124713582
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713599'}}]
# description already exists
# Q124713599
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713666'}}]
# description already exists
# Q124713666
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713704'}}]
# description already exists
# Q124713704
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713726'}}]
# description already exists
# Q124713726
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713734'}}]
# description already exists
# Q124713734
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713737'}}]
# description already exists
# Q124713737
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713743'}}]
# description already exists
# Q124713743
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713750'}}]
# description already exists
# Q124713750
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713753'}}]
# description already exists
# Q124713753
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713759'}}]
# description already exists
# Q124713759
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713772'}}]
# description already exists
# Q124713772
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713799'}}]
# description already exists
# Q124713799
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713821'}}]
# description already exists
# Q124713821
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713827'}}]
# description already exists
# Q124713827
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713828'}}]
# description already exists
# Q124713828
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713831'}}]
# description already exists
# Q124713831
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713834'}}]
# description already exists
# Q124713834
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713843'}}]
# description already exists
# Q124713843
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713850'}}]
# description already exists
# Q124713850
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713854'}}]
# description already exists
# Q124713854
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713860'}}]
# description already exists
# Q124713860
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713880'}}]
# description already exists
# Q124713880
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713890'}}]
# description already exists
# Q124713890
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713905'}}]
# description already exists
# Q124713905
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713921'}}]
# description already exists
# Q124713921
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713940'}}]
# description already exists
# Q124713940
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713956'}}]
# description already exists
# Q124713956
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713965'}}]
# description already exists
# Q124713965
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713976'}}]
# description already exists
# Q124713976
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713988'}}]
# description already exists
# Q124713988
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124713997'}}]
# description already exists
# Q124713997
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714027'}}]
# description already exists
# Q124714027
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714044'}}]
# description already exists
# Q124714044
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714056'}}]
# description already exists
# Q124714056
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714068'}}]
# description already exists
# Q124714068
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714075'}}]
# description already exists
# Q124714075
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714085'}}]
# description already exists
# Q124714085
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714095'}}]
# description already exists
# Q124714095
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714107'}}]
# description already exists
# Q124714107
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124714118'}}]
# description already exists
# Q124714118
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# ...
# description already exists
# Q124719238
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719267'}}]
# description already exists
# Q124719267
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719288'}}]
# description already exists
# Q124719288
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719321'}}]
# description already exists
# Q124719321
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719335'}}]
# description already exists
# Q124719335
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719349'}}]
# description already exists
# Q124719349
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719361'}}]
# description already exists
# Q124719361
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719374'}}]
# description already exists
# Q124719374
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719392'}}]
# description already exists
# Q124719392
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719406'}}]
# description already exists
# Q124719406
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719422'}}]
# description already exists
# Q124719422
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719439'}}]
# description already exists
# Q124719439
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719457'}}]
# Sleeping for 3.3 seconds, 2024-03-03 21:40:29
# Q124719457
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719457'}}]
# Sleeping for 9.3 seconds, 2024-03-03 21:40:33
# Q124719457
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719494'}}]
# description already exists
# Q124719494
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719516'}}]
# Sleeping for 8.4 seconds, 2024-03-03 21:40:44
# Q124719516
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719529'}}]
# description already exists
# Q124719529
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719516'}}]
# Sleeping for 8.7 seconds, 2024-03-03 21:40:53
# Q124719516
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719552'}}]
# description already exists
# Q124719552
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719580'}}]
# Sleeping for 8.8 seconds, 2024-03-03 21:41:03
# Q124719580
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719580'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:41:13
# Q124719580
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719609'}}]
# description already exists
# Q124719609
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719631'}}]
# description already exists
# Q124719631
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719653'}}]
# description already exists
# Q124719653
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719683'}}]
# description already exists
# Q124719683
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719733'}}]
# description already exists
# Q124719733
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719770'}}]
# Sleeping for 7.0 seconds, 2024-03-03 21:41:25
# Q124719770
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719770'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:41:33
# Q124719770
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719791'}}]
# description already exists
# Q124719791
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719804'}}]
# description already exists
# Q124719804
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719850'}}]
# description already exists
# Q124719850
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719868'}}]
# description already exists
# Q124719868
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719885'}}]
# description already exists
# Q124719885
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719903'}}]
# description already exists
# Q124719903
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719919'}}]
# description already exists
# Q124719919
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719928'}}]
# description already exists
# Q124719928
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719971'}}]
# description already exists
# Q124719971
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719994'}}]
# Q124719994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719994'}}]
# Sleeping for 9.3 seconds, 2024-03-03 21:41:53
# Q124719994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719994'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:42:03
# Q124719994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719994'}}]
# Sleeping for 9.1 seconds, 2024-03-03 21:42:13
# Q124719994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124719994'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:42:23
# Q124719994
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720020'}}]
# description already exists
# Q124720020
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720034'}}]
# description already exists
# Q124720034
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720180'}}]
# description already exists
# Q124720180
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720430'}}]
# description already exists
# Q124720430
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720636'}}]
# Sleeping for 7.3 seconds, 2024-03-03 21:42:35
# Q124720636
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720636'}}]
# Sleeping for 9.3 seconds, 2024-03-03 21:42:43
# Q124720636
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720882'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:42:53
# Q124720882
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124720882'}}]
# Sleeping for 9.2 seconds, 2024-03-03 21:43:03
# Q124720882
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721070'}}]
# description already exists
# Q124721070
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721126'}}]
# description already exists
# Q124721126
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721166'}}]
# description already exists
# Q124721166
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721190'}}]
# description already exists
# Q124721190
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721207'}}]
# description already exists
# Q124721207
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721228'}}]
# Sleeping for 6.9 seconds, 2024-03-03 21:43:15
# Q124721228
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721228'}}]
# Sleeping for 9.3 seconds, 2024-03-03 21:43:23
# Q124721228
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721238'}}]
# description already exists
# Q124721238
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721250'}}]
# description already exists
# Q124721250
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721270'}}]
# description already exists
# Q124721270
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721299'}}]
# description already exists
# Q124721299
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721517'}}]
# description already exists
# Q124721517
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124721918'}}]
# description already exists
# Q124721918
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124722307'}}]
# description already exists
# Q124722307
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124722697'}}]
# description already exists
# Q124722697
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124723075'}}]
# description already exists
# Q124723075
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q124723470'}}]
# description already exists
# Q124723470
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent

# %%
# after the proteins are added every gene can get the link to the protein in encoeds

def add_encodes_to_gene(df_row: pd.Series): 
    gwa = GeneWikidataAdder(df_row, False)
    gwa.encodes_protein(df_row["wd_gene_id"])

# %%
df.apply(add_encodes_to_gene, axis=1)
# Out:
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# claim already existent
# Sleeping for 3.1 seconds, 2024-03-03 21:43:39
# Sleeping for 8.0 seconds, 2024-03-03 21:43:44
# Sleeping for 9.3 seconds, 2024-03-03 21:43:53
# Sleeping for 9.3 seconds, 2024-03-03 21:44:03
# Sleeping for 9.3 seconds, 2024-03-03 21:44:13
# Sleeping for 9.3 seconds, 2024-03-03 21:44:23
# Sleeping for 9.3 seconds, 2024-03-03 21:44:33
# Sleeping for 9.2 seconds, 2024-03-03 21:44:43
# Sleeping for 9.2 seconds, 2024-03-03 21:44:53
# Sleeping for 9.4 seconds, 2024-03-03 21:45:03
# Sleeping for 9.4 seconds, 2024-03-03 21:45:13
# Sleeping for 9.3 seconds, 2024-03-03 21:45:23
# Sleeping for 9.2 seconds, 2024-03-03 21:45:33
# Sleeping for 9.3 seconds, 2024-03-03 21:45:43
# Sleeping for 9.4 seconds, 2024-03-03 21:45:53
# Sleeping for 9.2 seconds, 2024-03-03 21:46:03
# Sleeping for 9.2 seconds, 2024-03-03 21:46:13
# Sleeping for 9.3 seconds, 2024-03-03 21:46:23
# Sleeping for 9.3 seconds, 2024-03-03 21:46:33
# Sleeping for 9.3 seconds, 2024-03-03 21:46:43
# Sleeping for 9.3 seconds, 2024-03-03 21:46:53
# Sleeping for 9.4 seconds, 2024-03-03 21:47:03
# Sleeping for 9.4 seconds, 2024-03-03 21:47:13
# Sleeping for 9.3 seconds, 2024-03-03 21:47:23
# Sleeping for 9.2 seconds, 2024-03-03 21:47:33
# Sleeping for 9.3 seconds, 2024-03-03 21:47:43
# Sleeping for 9.3 seconds, 2024-03-03 21:47:53
# Sleeping for 9.2 seconds, 2024-03-03 21:48:03
# Sleeping for 9.3 seconds, 2024-03-03 21:48:13
# Sleeping for 9.4 seconds, 2024-03-03 21:48:23
# Sleeping for 9.3 seconds, 2024-03-03 21:48:33
# Sleeping for 9.2 seconds, 2024-03-03 21:48:43
# Sleeping for 9.3 seconds, 2024-03-03 21:48:53
# Sleeping for 9.3 seconds, 2024-03-03 21:49:03
# Sleeping for 9.3 seconds, 2024-03-03 21:49:13
# Sleeping for 9.2 seconds, 2024-03-03 21:49:23
# Sleeping for 9.2 seconds, 2024-03-03 21:49:33
# Sleeping for 9.2 seconds, 2024-03-03 21:49:43
# Sleeping for 9.3 seconds, 2024-03-03 21:49:53
# Sleeping for 9.3 seconds, 2024-03-03 21:50:03
# Sleeping for 9.3 seconds, 2024-03-03 21:50:13
# Sleeping for 9.3 seconds, 2024-03-03 21:50:23
# Sleeping for 9.3 seconds, 2024-03-03 21:50:33
# Sleeping for 9.3 seconds, 2024-03-03 21:50:43
# Sleeping for 9.2 seconds, 2024-03-03 21:50:54
# Sleeping for 9.3 seconds, 2024-03-03 21:51:03
# Sleeping for 9.2 seconds, 2024-03-03 21:51:14
# Sleeping for 9.3 seconds, 2024-03-03 21:51:23
# Sleeping for 9.2 seconds, 2024-03-03 21:51:34
# Sleeping for 9.2 seconds, 2024-03-03 21:51:44
# Sleeping for 9.1 seconds, 2024-03-03 21:51:54
# Sleeping for 9.2 seconds, 2024-03-03 21:52:04
# Sleeping for 9.2 seconds, 2024-03-03 21:52:14
# Sleeping for 9.3 seconds, 2024-03-03 21:52:24
# Sleeping for 9.2 seconds, 2024-03-03 21:52:34
# Sleeping for 9.3 seconds, 2024-03-03 21:52:44
# Sleeping for 9.0 seconds, 2024-03-03 21:52:55
# Sleeping for 9.1 seconds, 2024-03-03 21:53:04
# Sleeping for 9.3 seconds, 2024-03-03 21:53:14
# Sleeping for 9.2 seconds, 2024-03-03 21:53:24
# Sleeping for 9.2 seconds, 2024-03-03 21:53:34
# Sleeping for 9.3 seconds, 2024-03-03 21:53:44
# Sleeping for 9.3 seconds, 2024-03-03 21:53:54
# Sleeping for 7.1 seconds, 2024-03-03 21:54:07
# Sleeping for 9.2 seconds, 2024-03-03 21:54:14
# Sleeping for 9.3 seconds, 2024-03-03 21:54:24
# Sleeping for 9.3 seconds, 2024-03-03 21:54:34
# Sleeping for 9.3 seconds, 2024-03-03 21:54:44
# Sleeping for 9.2 seconds, 2024-03-03 21:54:54
# Sleeping for 9.4 seconds, 2024-03-03 21:55:04
# Sleeping for 9.0 seconds, 2024-03-03 21:55:15
# Sleeping for 9.2 seconds, 2024-03-03 21:55:24
# Sleeping for 9.2 seconds, 2024-03-03 21:55:34
# Sleeping for 9.1 seconds, 2024-03-03 21:55:45
# Sleeping for 9.3 seconds, 2024-03-03 21:55:54
# Sleeping for 9.2 seconds, 2024-03-03 21:56:04
# Sleeping for 9.2 seconds, 2024-03-03 21:56:15
# Sleeping for 9.3 seconds, 2024-03-03 21:56:24
# Sleeping for 9.3 seconds, 2024-03-03 21:56:34
# Sleeping for 9.2 seconds, 2024-03-03 21:56:45
# Sleeping for 9.2 seconds, 2024-03-03 21:56:55
# Sleeping for 9.4 seconds, 2024-03-03 21:57:04
# Sleeping for 9.1 seconds, 2024-03-03 21:57:15
# Sleeping for 9.3 seconds, 2024-03-03 21:57:24
# Sleeping for 9.3 seconds, 2024-03-03 21:57:34
# Sleeping for 9.2 seconds, 2024-03-03 21:57:45
# Sleeping for 9.4 seconds, 2024-03-03 21:57:54
# Sleeping for 9.3 seconds, 2024-03-03 21:58:04
# Sleeping for 9.0 seconds, 2024-03-03 21:58:15
# Sleeping for 9.3 seconds, 2024-03-03 21:58:25
# Sleeping for 9.3 seconds, 2024-03-03 21:58:35
# Sleeping for 9.2 seconds, 2024-03-03 21:58:45
# Sleeping for 9.1 seconds, 2024-03-03 21:58:55
# Sleeping for 9.1 seconds, 2024-03-03 21:59:05
# Sleeping for 9.3 seconds, 2024-03-03 21:59:15
# Sleeping for 9.3 seconds, 2024-03-03 21:59:25
# Sleeping for 9.3 seconds, 2024-03-03 21:59:35
# Sleeping for 9.2 seconds, 2024-03-03 21:59:45
# Sleeping for 9.2 seconds, 2024-03-03 21:59:55
# Sleeping for 9.2 seconds, 2024-03-03 22:00:05
# Sleeping for 9.3 seconds, 2024-03-03 22:00:15
# Sleeping for 9.3 seconds, 2024-03-03 22:00:25
# Sleeping for 9.3 seconds, 2024-03-03 22:00:35
# Sleeping for 9.1 seconds, 2024-03-03 22:00:45
# Sleeping for 9.3 seconds, 2024-03-03 22:00:55
# Sleeping for 9.2 seconds, 2024-03-03 22:01:05
# Sleeping for 9.4 seconds, 2024-03-03 22:01:15
# Sleeping for 9.3 seconds, 2024-03-03 22:01:25
# Sleeping for 9.2 seconds, 2024-03-03 22:01:35
# Sleeping for 9.4 seconds, 2024-03-03 22:01:45
# Sleeping for 9.3 seconds, 2024-03-03 22:01:55
# Sleeping for 9.1 seconds, 2024-03-03 22:02:05
# Sleeping for 9.3 seconds, 2024-03-03 22:02:15
# Sleeping for 9.4 seconds, 2024-03-03 22:02:25
# Sleeping for 9.4 seconds, 2024-03-03 22:02:35
# Sleeping for 9.2 seconds, 2024-03-03 22:02:45
# Sleeping for 9.3 seconds, 2024-03-03 22:02:55
# Sleeping for 8.7 seconds, 2024-03-03 22:03:05
# Sleeping for 9.3 seconds, 2024-03-03 22:03:15
# Sleeping for 9.2 seconds, 2024-03-03 22:03:25
# Sleeping for 9.2 seconds, 2024-03-03 22:03:35
# Sleeping for 9.2 seconds, 2024-03-03 22:03:45
# Sleeping for 9.3 seconds, 2024-03-03 22:03:55
# Sleeping for 9.3 seconds, 2024-03-03 22:04:05
# Sleeping for 9.3 seconds, 2024-03-03 22:04:15
# Sleeping for 9.3 seconds, 2024-03-03 22:04:25
# Sleeping for 9.3 seconds, 2024-03-03 22:04:35
# Sleeping for 9.3 seconds, 2024-03-03 22:04:45
# Sleeping for 9.2 seconds, 2024-03-03 22:04:55
# Sleeping for 9.4 seconds, 2024-03-03 22:05:05
# Sleeping for 9.4 seconds, 2024-03-03 22:05:15
# Sleeping for 9.3 seconds, 2024-03-03 22:05:25
# Sleeping for 9.2 seconds, 2024-03-03 22:05:35
# Sleeping for 9.4 seconds, 2024-03-03 22:05:45
# Sleeping for 9.2 seconds, 2024-03-03 22:05:55
# Sleeping for 9.3 seconds, 2024-03-03 22:06:05
# Sleeping for 9.3 seconds, 2024-03-03 22:06:15
# Sleeping for 9.1 seconds, 2024-03-03 22:06:25
# Sleeping for 9.3 seconds, 2024-03-03 22:06:35
# Sleeping for 9.2 seconds, 2024-03-03 22:06:45
# Sleeping for 9.3 seconds, 2024-03-03 22:06:55
# Sleeping for 9.4 seconds, 2024-03-03 22:07:05
# Sleeping for 9.2 seconds, 2024-03-03 22:07:15
# Sleeping for 9.4 seconds, 2024-03-03 22:07:25
# Sleeping for 9.3 seconds, 2024-03-03 22:07:35
# Sleeping for 9.3 seconds, 2024-03-03 22:07:45
# Sleeping for 9.2 seconds, 2024-03-03 22:07:55
# Sleeping for 9.3 seconds, 2024-03-03 22:08:05
# Sleeping for 9.3 seconds, 2024-03-03 22:08:15
# Sleeping for 9.3 seconds, 2024-03-03 22:08:25
# Sleeping for 9.2 seconds, 2024-03-03 22:08:35
# Sleeping for 9.2 seconds, 2024-03-03 22:08:45
# Sleeping for 9.2 seconds, 2024-03-03 22:08:55
# Sleeping for 9.3 seconds, 2024-03-03 22:09:05
# Sleeping for 9.2 seconds, 2024-03-03 22:09:15
# Sleeping for 9.3 seconds, 2024-03-03 22:09:25
# Sleeping for 9.3 seconds, 2024-03-03 22:09:35
# Sleeping for 9.3 seconds, 2024-03-03 22:09:45
# Sleeping for 9.3 seconds, 2024-03-03 22:09:55
# Sleeping for 9.2 seconds, 2024-03-03 22:10:05
# Sleeping for 9.3 seconds, 2024-03-03 22:10:15
# Sleeping for 9.3 seconds, 2024-03-03 22:10:25
# Sleeping for 9.2 seconds, 2024-03-03 22:10:35
# Sleeping for 9.3 seconds, 2024-03-03 22:10:45
# Sleeping for 9.3 seconds, 2024-03-03 22:10:55
# Sleeping for 9.3 seconds, 2024-03-03 22:11:05
# Sleeping for 9.3 seconds, 2024-03-03 22:11:15
# Sleeping for 9.3 seconds, 2024-03-03 22:11:25
# Sleeping for 9.2 seconds, 2024-03-03 22:11:35
# Sleeping for 9.2 seconds, 2024-03-03 22:11:45
# Sleeping for 9.3 seconds, 2024-03-03 22:11:55
# Sleeping for 9.2 seconds, 2024-03-03 22:12:05
# Sleeping for 9.2 seconds, 2024-03-03 22:12:15
# Sleeping for 9.1 seconds, 2024-03-03 22:12:26
# Sleeping for 9.2 seconds, 2024-03-03 22:12:35
# Sleeping for 9.2 seconds, 2024-03-03 22:12:45
# Sleeping for 9.2 seconds, 2024-03-03 22:12:55
# Sleeping for 9.3 seconds, 2024-03-03 22:13:05
# Sleeping for 9.3 seconds, 2024-03-03 22:13:15
# Sleeping for 9.4 seconds, 2024-03-03 22:13:25
# Sleeping for 9.2 seconds, 2024-03-03 22:13:36
# Sleeping for 9.2 seconds, 2024-03-03 22:13:46
# Sleeping for 9.2 seconds, 2024-03-03 22:13:55
# Sleeping for 9.3 seconds, 2024-03-03 22:14:05
# Sleeping for 9.3 seconds, 2024-03-03 22:14:15
# Sleeping for 9.3 seconds, 2024-03-03 22:14:25
# Sleeping for 9.3 seconds, 2024-03-03 22:14:35
# Sleeping for 9.3 seconds, 2024-03-03 22:14:45
# Sleeping for 9.3 seconds, 2024-03-03 22:14:55
# Sleeping for 9.3 seconds, 2024-03-03 22:15:06
# Sleeping for 9.3 seconds, 2024-03-03 22:15:15
# Sleeping for 9.4 seconds, 2024-03-03 22:15:25
# Sleeping for 9.3 seconds, 2024-03-03 22:15:36
# Sleeping for 9.4 seconds, 2024-03-03 22:15:45
# Sleeping for 9.1 seconds, 2024-03-03 22:15:56
# Sleeping for 9.3 seconds, 2024-03-03 22:16:06
# Sleeping for 9.4 seconds, 2024-03-03 22:16:15
# Sleeping for 9.3 seconds, 2024-03-03 22:16:26
# Sleeping for 9.0 seconds, 2024-03-03 22:16:36
# Sleeping for 9.4 seconds, 2024-03-03 22:16:45
# Sleeping for 9.3 seconds, 2024-03-03 22:16:56
# Sleeping for 9.4 seconds, 2024-03-03 22:17:06
# Sleeping for 9.3 seconds, 2024-03-03 22:17:16
# Sleeping for 9.3 seconds, 2024-03-03 22:17:26
# Sleeping for 9.3 seconds, 2024-03-03 22:17:36
# Sleeping for 9.3 seconds, 2024-03-03 22:17:46
# Sleeping for 9.3 seconds, 2024-03-03 22:17:56
# Sleeping for 9.4 seconds, 2024-03-03 22:18:06
# Sleeping for 9.3 seconds, 2024-03-03 22:18:16
# Sleeping for 9.4 seconds, 2024-03-03 22:18:26
# Sleeping for 9.3 seconds, 2024-03-03 22:18:36
# Sleeping for 9.3 seconds, 2024-03-03 22:18:46
# Sleeping for 9.4 seconds, 2024-03-03 22:18:56
# Sleeping for 9.4 seconds, 2024-03-03 22:19:06
# Sleeping for 9.2 seconds, 2024-03-03 22:19:16
# Sleeping for 9.4 seconds, 2024-03-03 22:19:26
# Sleeping for 9.3 seconds, 2024-03-03 22:19:36
# Sleeping for 9.4 seconds, 2024-03-03 22:19:46
# Sleeping for 9.3 seconds, 2024-03-03 22:19:56
# Sleeping for 9.2 seconds, 2024-03-03 22:20:06
# Sleeping for 9.3 seconds, 2024-03-03 22:20:16
# Sleeping for 9.4 seconds, 2024-03-03 22:20:26
# Sleeping for 9.3 seconds, 2024-03-03 22:20:36
# Sleeping for 9.2 seconds, 2024-03-03 22:20:46
# Sleeping for 9.3 seconds, 2024-03-03 22:20:56
# Sleeping for 9.4 seconds, 2024-03-03 22:21:06
# Sleeping for 9.2 seconds, 2024-03-03 22:21:16
# Sleeping for 9.2 seconds, 2024-03-03 22:21:26
# Sleeping for 9.2 seconds, 2024-03-03 22:21:36
# Sleeping for 9.3 seconds, 2024-03-03 22:21:46
# Sleeping for 9.1 seconds, 2024-03-03 22:21:56
# Sleeping for 9.3 seconds, 2024-03-03 22:22:06
# Sleeping for 9.3 seconds, 2024-03-03 22:22:16
# Sleeping for 9.3 seconds, 2024-03-03 22:22:26
# Sleeping for 9.2 seconds, 2024-03-03 22:22:36
# Sleeping for 9.2 seconds, 2024-03-03 22:22:46
# Sleeping for 9.3 seconds, 2024-03-03 22:22:56
# Sleeping for 9.4 seconds, 2024-03-03 22:23:06
# Sleeping for 9.3 seconds, 2024-03-03 22:23:16
# Sleeping for 9.3 seconds, 2024-03-03 22:23:26
# Sleeping for 9.3 seconds, 2024-03-03 22:23:36
# Sleeping for 9.3 seconds, 2024-03-03 22:23:46
# Sleeping for 9.1 seconds, 2024-03-03 22:23:56
# Sleeping for 9.2 seconds, 2024-03-03 22:24:06
# Sleeping for 9.2 seconds, 2024-03-03 22:24:16
# Sleeping for 9.4 seconds, 2024-03-03 22:24:26
# Sleeping for 9.2 seconds, 2024-03-03 22:24:36
# Sleeping for 9.3 seconds, 2024-03-03 22:24:46
# Sleeping for 9.3 seconds, 2024-03-03 22:24:56
# Sleeping for 9.3 seconds, 2024-03-03 22:25:06
# Sleeping for 9.2 seconds, 2024-03-03 22:25:16
# Sleeping for 9.3 seconds, 2024-03-03 22:25:26
# Sleeping for 9.3 seconds, 2024-03-03 22:25:36
# Sleeping for 9.2 seconds, 2024-03-03 22:25:46
# Sleeping for 9.2 seconds, 2024-03-03 22:25:56
# Sleeping for 9.3 seconds, 2024-03-03 22:26:06
# Sleeping for 9.3 seconds, 2024-03-03 22:26:16
# Sleeping for 9.3 seconds, 2024-03-03 22:26:26
# Sleeping for 9.2 seconds, 2024-03-03 22:26:36
# Sleeping for 9.4 seconds, 2024-03-03 22:26:46
# Sleeping for 9.3 seconds, 2024-03-03 22:26:56
# Sleeping for 9.2 seconds, 2024-03-03 22:27:06
# Sleeping for 9.3 seconds, 2024-03-03 22:27:16
# Sleeping for 9.2 seconds, 2024-03-03 22:27:26
# Sleeping for 9.3 seconds, 2024-03-03 22:27:36
# Sleeping for 9.2 seconds, 2024-03-03 22:27:46
# Sleeping for 9.4 seconds, 2024-03-03 22:27:56
# Sleeping for 9.3 seconds, 2024-03-03 22:28:06
# Sleeping for 9.3 seconds, 2024-03-03 22:28:16
# Sleeping for 9.2 seconds, 2024-03-03 22:28:26
# Sleeping for 9.3 seconds, 2024-03-03 22:28:36
# Sleeping for 9.4 seconds, 2024-03-03 22:28:46
# Sleeping for 9.2 seconds, 2024-03-03 22:28:56
# Sleeping for 9.2 seconds, 2024-03-03 22:29:06
# Sleeping for 9.3 seconds, 2024-03-03 22:29:16
# Sleeping for 9.3 seconds, 2024-03-03 22:29:26
# Sleeping for 9.4 seconds, 2024-03-03 22:29:36
# Sleeping for 9.2 seconds, 2024-03-03 22:29:46
# Sleeping for 9.3 seconds, 2024-03-03 22:29:56
# Sleeping for 9.2 seconds, 2024-03-03 22:30:06
# Sleeping for 9.3 seconds, 2024-03-03 22:30:16
# Sleeping for 9.2 seconds, 2024-03-03 22:30:26
# Sleeping for 9.2 seconds, 2024-03-03 22:30:36
# Sleeping for 9.3 seconds, 2024-03-03 22:30:46
# Sleeping for 9.3 seconds, 2024-03-03 22:30:56
# Sleeping for 9.2 seconds, 2024-03-03 22:31:06
# Sleeping for 9.2 seconds, 2024-03-03 22:31:16
# Sleeping for 9.3 seconds, 2024-03-03 22:31:26
# Sleeping for 9.2 seconds, 2024-03-03 22:31:37
# Sleeping for 9.3 seconds, 2024-03-03 22:31:46
# Sleeping for 9.1 seconds, 2024-03-03 22:31:57
# Sleeping for 9.3 seconds, 2024-03-03 22:32:06
# Sleeping for 9.3 seconds, 2024-03-03 22:32:16
# Sleeping for 9.2 seconds, 2024-03-03 22:32:27
# Sleeping for 9.3 seconds, 2024-03-03 22:32:36
# Sleeping for 9.2 seconds, 2024-03-03 22:32:47
# Sleeping for 9.3 seconds, 2024-03-03 22:32:57
# Sleeping for 9.2 seconds, 2024-03-03 22:33:07
# Sleeping for 9.3 seconds, 2024-03-03 22:33:16
# Sleeping for 9.3 seconds, 2024-03-03 22:33:27
# Sleeping for 9.3 seconds, 2024-03-03 22:33:37
# Sleeping for 9.0 seconds, 2024-03-03 22:33:47
# Sleeping for 9.3 seconds, 2024-03-03 22:33:57
# Sleeping for 9.2 seconds, 2024-03-03 22:34:07
# Sleeping for 9.4 seconds, 2024-03-03 22:34:16
# Sleeping for 9.2 seconds, 2024-03-03 22:34:27
# Sleeping for 9.2 seconds, 2024-03-03 22:34:37
# 0       None
# 2       None
# 4       None
# 20      None
# 21      None
#         ...
# 5562    None
# 5614    None
# 5626    None
# 5628    None
# 5630    None
# Length: 312, dtype: object

# %% [markdown]
# ## Discussion and Conclusion
#
# In conclusion, it can be noted that data has been successfully queried from two databases (GenBank and RefSeq). However, due to incomplete data in some cases (references to higher taxons, the use of abbreviations leading to ambiguity in bacterial species, or discrepancies between GenBank and RefSeq in providing different names), the originally extensive dataset of approximately 10,000 entries has been reduced to a more manageable 300 entries that can be reliably implemented. Most of the found data is newly entered into wikidata, while some data instances were already present. The below shown dataframe displays the (newly) created wikidata ID's for the bacterial strain, gene and the encoded protein. For example the bacterial strain "Campylobacter jejuni subsp. jejuni 81-176" (Q21382941, already present in wikidata) has the gene "Campylobacter jejuni subsp. jejuni 81-176 pTet tet(O)" (Q124707459, newly entered into wikidata) which encodes the protein "tetracycline resistance ribosomal protection protein Tet(O)" (Q124720636, newly entered into wikidata).
#
# Following the model of other bacteria, genes, and proteins (with the addition of the tag "response to antibiotic" here), these selected entries are implemented. However, unlike other genes already present in Wikidata, the "Entrez Gene ID" reference could not be found. Despite this missing link, the genes are implemented in Wikidata with the hope that users will contribute and add this information in the future.
#
# In summary, it can be concluded that a small percentage of all antibiotic-resistant bacteria known to NCBI could potentially be implemented in Wikidata. The main obstacles to implementing further data are the incomplete or non-standardized entries in GenBank and RefSeq databases and the absence of expert knowledge.

# %%
df[["strain_wd_id", "wd_gene_id", "wd_protein_id"]].sample(10)
# Out:
#      strain_wd_id  wd_gene_id wd_protein_id
# 5325    Q21382941  Q124707459    Q124720636
# 641    Q124691337  Q124705134    Q124711886
# 5214   Q124695818  Q124707428    Q124719919
# 5194    Q21398305  Q124707421    Q124719885
# 2940   Q124691944  Q124705925    Q124714396
# 4438    Q21382032  Q124707110    Q124719010
# 414     Q21102994  Q124705024    Q124707800
# 467     Q21398129  Q124705073    Q124707864
# 192    Q124691052  Q124704923    Q124707729
# 259    Q124691090  Q124704946    Q124707745

# %% [markdown]
# ## Link to GitHub
#
#
# https://github.com/gjmm07/DS_LOD_and_Knowledge_Graphs_2023_Finn_Heydemann

# %% [markdown]
# ## Litarture

# %% [markdown]
# [1] Salam et al.: Antimicrobial Resistance: A Growing Serious Threat for Global Public Health, 2023
#
# [2] National Center for Biotechnolog Information: National Database of Antibiotic Resistant Organisms (NDARO), URL: https://www.ncbi.nlm.nih.gov/pathogens/antimicrobial-resistance/, last accessed: 26.02.2024
